# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
# %matplotlib inline

sys.path.append('..')
import theanomics.neuralnetwork as nn
from theanomics import learn, utils
from models import vae_MNIST_model

import theano
import theano.tensor as T
from lasagne import layers

np.random.seed(247)   # for reproducibility

# %%
def load_dataset(data_path):
    import gzip
    def load_mnist_images(filename):
        with gzip.open(filename, 'rb') as f:
            data = np.frombuffer(f.read(), np.uint8, offset=16)
        data = data.reshape(-1, 28*28)
        return data / np.float32(256)

    def load_mnist_labels(filename):
        with gzip.open(filename, 'rb') as f:
            data = np.frombuffer(f.read(), np.uint8, offset=8)
        return data

    # We can now download and read the training and test set images and labels.
    X_train = load_mnist_images(os.path.join(data_path,'train-images-idx3-ubyte.gz'))
    y_train = load_mnist_labels(os.path.join(data_path,'train-labels-idx1-ubyte.gz'))
    X_test = load_mnist_images(os.path.join(data_path,'t10k-images-idx3-ubyte.gz'))
    y_test = load_mnist_labels(os.path.join(data_path,'t10k-labels-idx1-ubyte.gz'))

    # We reserve the last 10000 training examples for validation.
    X_train, X_val = X_train[:-10000], X_train[-10000:]
    y_train, y_val = y_train[:-10000], y_train[-10000:]

    # We just return all the arrays in order, as expected in main().
    # (It doesn't matter how we do this as long as we can read them again.)
    return X_train, y_train, X_val, y_val, X_test, y_test


data_path = '../../data/MNIST'
X_train, y_train, X_val, y_val, X_test, y_test = load_dataset(data_path)

# %%
input_shape = list(X_train.shape)
input_shape[0] = None
network, placeholders, optimization = vae_MNIST_model.model(input_shape)

# %%
# build neural network class
nnmodel = nn.NeuralNet(network, placeholders)
nnmodel.inspect_layers()

# set output file paths
output_name = 'MNIST_vae'
results_path = utils.make_directory(data_path, 'Results')
results_path = utils.make_directory(results_path, output_name)
file_path = os.path.join(results_path, output_name)
nntrainer = nn.NeuralTrainer(nnmodel, optimization, save='best', file_path=file_path)
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1:
# <lasagne.layers.input.InputLayer object at 0x11a735c88>
# shape:(None, 784)
# layer2:
# <lasagne.layers.dense.DenseLayer object at 0x11a735ef0>
# shape:(None, 512)
# parameters: W
# layer3:
# <lasagne.layers.special.BiasLayer object at 0x10d33a780>
# shape:(None, 512)
# parameters: b
# layer4:
# <lasagne.layers.special.NonlinearityLayer object at 0x11a75e390>
# shape:(None, 512)
# layer5:
# <lasagne.layers.dense.DenseLayer object at 0x11a75e518>
# shape:(None, 64)
# parameters: W
# layer6:
# <lasagne.layers.special.BiasLayer object at 0x11a735ba8>
# shape:(None, 64)
# parameters: b
# layer7:
# <lasagne.layers.special.NonlinearityLayer object at 0x11a75e748>
# shape:(None, 64)
# layer8:
# <lasagne.layers.dense.DenseLayer object at 0x105b03a20>
# shape:(None, 2)
# parameters: W, b
# layer9:
# <lasagne.layers.dense.DenseLayer object at 0x105b4e0b8>
# shape:(None, 2)
# parameters: W, b
# layer10:
# <theanomics.build_network.VariationalSampleLayer object at 0x105b039b0>
# shape:(None, 2)
# layer11:
# <lasagne.layers.dense.DenseLayer object at 0x11a7b2518>
# shape:(None, 64)
# parameters: W
# layer12:
# <lasagne.layers.special.BiasLayer object at 0x11a75e588>
# shape:(None, 64)
# parameters: b
# layer13:
# <lasagne.layers.special.NonlinearityLayer object at 0x11a7b26d8>
# shape:(None, 64)
# layer14:
# <lasagne.layers.dense.DenseLayer object at 0x11a7b2908>
# shape:(None, 512)
# parameters: W
# layer15:
# <lasagne.layers.special.BiasLayer object at 0x11a7b2320>
# shape:(None, 512)
# parameters: b
# layer16:
# <lasagne.layers.special.NonlinearityLayer object at 0x11a7b2ac8>
# shape:(None, 512)
# layer17:
# <lasagne.layers.dense.DenseLayer object at 0x11a7b2cf8>
# shape:(None, 784)
# parameters: W
# layer18:
# <lasagne.layers.special.BiasLayer object at 0x11a7b2898>
# shape:(None, 784)
# parameters: b
# layer19:
# <lasagne.layers.special.NonlinearityLayer object at 0x11a7b2eb8>
# shape:(None, 784)
# ----------------------------------------------------------------------------
# WARNING (theano.gof.compilelock): Overriding existing lock by dead process '81491' (I am process '81931')

# %%
# train model
learn.train_minibatch(nntrainer, data={'train': X_train, 'valid': X_val}, 
                              batch_size=100, num_epochs=500, patience=50, verbose=0)
# Out:
#   valid loss:		391.15286
#   valid squared loss:	0.13068
# output: not found in network
#   valid loss:		255.18656
#   valid squared loss:	0.07190
# output: not found in network
#   valid loss:		223.53683
#   valid squared loss:	0.06803
# output: not found in network
#   valid loss:		213.04140
#   valid squared loss:	0.06641
# output: not found in network
#   valid loss:		208.53213
#   valid squared loss:	0.06543
# output: not found in network
#   valid loss:		206.48123
#   valid squared loss:	0.06536
# output: not found in network
#   valid loss:		204.71567
#   valid squared loss:	0.06492
# output: not found in network
#   valid loss:		203.37074
#   valid squared loss:	0.06436
# output: not found in network
#   valid loss:		202.14211
#   valid squared loss:	0.06418
# output: not found in network
#   valid loss:		201.28887
#   valid squared loss:	0.06390
# output: not found in network
#   valid loss:		200.36719
#   valid squared loss:	0.06354
# output: not found in network
#   valid loss:		199.42789
#   valid squared loss:	0.06332
# output: not found in network
#   valid loss:		197.02032
#   valid squared loss:	0.06206
# output: not found in network
#   valid loss:		194.66576
#   valid squared loss:	0.06063
# output: not found in network
#   valid loss:		192.31924
#   valid squared loss:	0.05961
# output: not found in network
#   valid loss:		189.99907
#   valid squared loss:	0.05864
# output: not found in network
#   valid loss:		188.42420
#   valid squared loss:	0.05791
# output: not found in network
#   valid loss:		186.37237
#   valid squared loss:	0.05702
# output: not found in network
#   valid loss:		184.75042
#   valid squared loss:	0.05638
# output: not found in network
#   valid loss:		183.83104
#   valid squared loss:	0.05611
# output: not found in network
#   valid loss:		183.36010
#   valid squared loss:	0.05600
# output: not found in network
#   valid loss:		182.30187
#   valid squared loss:	0.05544
# output: not found in network
#   valid loss:		181.68980
#   valid squared loss:	0.05520
# output: not found in network
#   valid loss:		180.96495
#   valid squared loss:	0.05490
# output: not found in network
#   valid loss:		180.29148
#   valid squared loss:	0.05465
# output: not found in network
#   valid loss:		179.88718
#   valid squared loss:	0.05447
# output: not found in network
#   valid loss:		179.51556
#   valid squared loss:	0.05435
# output: not found in network
#   valid loss:		178.80890
#   valid squared loss:	0.05409
# output: not found in network
#   valid loss:		178.59375
#   valid squared loss:	0.05402
# output: not found in network
#   valid loss:		178.12546
#   valid squared loss:	0.05386
# output: not found in network
#   valid loss:		177.92222
#   valid squared loss:	0.05381
# output: not found in network
#   valid loss:		177.75534
#   valid squared loss:	0.05365
# output: not found in network
#   valid loss:		177.02021
#   valid squared loss:	0.05343
# output: not found in network
#   valid loss:		176.88219
#   valid squared loss:	0.05329
# output: not found in network
#   valid loss:		176.49657
#   valid squared loss:	0.05297
# output: not found in network
#   valid loss:		176.32145
#   valid squared loss:	0.05300
# output: not found in network
#   valid loss:		175.86399
#   valid squared loss:	0.05291
# output: not found in network
#   valid loss:		175.87165
#   valid squared loss:	0.05290
#   valid loss:		175.47295
#   valid squared loss:	0.05275
# output: not found in network
#   valid loss:		174.98405
#   valid squared loss:	0.05250
# output: not found in network
#   valid loss:		174.88354
#   valid squared loss:	0.05241
# output: not found in network
#   valid loss:		174.57582
#   valid squared loss:	0.05236
# output: not found in network
#   valid loss:		174.08772
#   valid squared loss:	0.05205
# output: not found in network
#   valid loss:		173.86459
#   valid squared loss:	0.05190
# output: not found in network
#   valid loss:		173.79136
#   valid squared loss:	0.05190
# output: not found in network
#   valid loss:		173.65432
#   valid squared loss:	0.05184
# output: not found in network
#   valid loss:		173.46399
#   valid squared loss:	0.05181
# output: not found in network
#   valid loss:		173.23477
#   valid squared loss:	0.05163
# output: not found in network
#   valid loss:		173.18509
#   valid squared loss:	0.05154
# output: not found in network
#   valid loss:		173.06576
#   valid squared loss:	0.05158
# output: not found in network
#   valid loss:		172.75079
#   valid squared loss:	0.05153
# output: not found in network
#   valid loss:		172.38651
#   valid squared loss:	0.05128
# output: not found in network
#   valid loss:		172.37115
#   valid squared loss:	0.05131
# output: not found in network
#   valid loss:		172.14019
#   valid squared loss:	0.05119
# output: not found in network
#   valid loss:		171.95064
#   valid squared loss:	0.05110
# output: not found in network
#   valid loss:		171.61702
#   valid squared loss:	0.05095
# output: not found in network
#   valid loss:		171.76715
#   valid squared loss:	0.05103
#   valid loss:		171.73214
#   valid squared loss:	0.05103
#   valid loss:		171.49970
#   valid squared loss:	0.05092
# output: not found in network
#   valid loss:		171.34853
#   valid squared loss:	0.05085
# output: not found in network
#   valid loss:		171.34638
#   valid squared loss:	0.05083
# output: not found in network
#   valid loss:		171.42499
#   valid squared loss:	0.05086
#   valid loss:		171.13258
#   valid squared loss:	0.05073
# output: not found in network
#   valid loss:		170.92132
#   valid squared loss:	0.05063
# output: not found in network
#   valid loss:		170.83579
#   valid squared loss:	0.05073
# output: not found in network
#   valid loss:		170.52233
#   valid squared loss:	0.05047
# output: not found in network
#   valid loss:		170.44004
#   valid squared loss:	0.05043
# output: not found in network
#   valid loss:		170.14333
#   valid squared loss:	0.05032
# output: not found in network
#   valid loss:		169.90365
#   valid squared loss:	0.05026
# output: not found in network
#   valid loss:		169.99620
#   valid squared loss:	0.05033
#   valid loss:		169.85205
#   valid squared loss:	0.05021
# output: not found in network
#   valid loss:		169.73950
#   valid squared loss:	0.05011
# output: not found in network
#   valid loss:		169.56227
#   valid squared loss:	0.05011
# output: not found in network
#   valid loss:		169.75720
#   valid squared loss:	0.05027
#   valid loss:		169.46655
#   valid squared loss:	0.05004
# output: not found in network
#   valid loss:		169.15425
#   valid squared loss:	0.04992
# output: not found in network
#   valid loss:		169.23556
#   valid squared loss:	0.04988
#   valid loss:		168.95640
#   valid squared loss:	0.04982
# output: not found in network
#   valid loss:		168.64977
#   valid squared loss:	0.04970
# output: not found in network
#   valid loss:		168.49005
#   valid squared loss:	0.04967
# output: not found in network
#   valid loss:		168.90038
#   valid squared loss:	0.04971
#   valid loss:		168.95536
#   valid squared loss:	0.04989
#   valid loss:		168.40010
#   valid squared loss:	0.04955
# output: not found in network
#   valid loss:		168.19026
#   valid squared loss:	0.04945
# output: not found in network
#   valid loss:		168.06152
#   valid squared loss:	0.04948
# output: not found in network
#   valid loss:		168.04983
#   valid squared loss:	0.04939
# output: not found in network
#   valid loss:		168.04668
#   valid squared loss:	0.04942
# output: not found in network
#   valid loss:		167.88944
#   valid squared loss:	0.04944
# output: not found in network
#   valid loss:		167.73745
#   valid squared loss:	0.04929
# output: not found in network
#   valid loss:		167.85576
#   valid squared loss:	0.04944
#   valid loss:		167.77502
#   valid squared loss:	0.04926
#   valid loss:		167.50252
#   valid squared loss:	0.04919
# output: not found in network
#   valid loss:		167.44071
#   valid squared loss:	0.04916
# output: not found in network
#   valid loss:		167.33125
#   valid squared loss:	0.04905
# output: not found in network
#   valid loss:		167.13057
#   valid squared loss:	0.04908
# output: not found in network
#   valid loss:		166.98576
#   valid squared loss:	0.04904
# output: not found in network
#   valid loss:		166.90834
#   valid squared loss:	0.04890
# output: not found in network
#   valid loss:		167.01719
#   valid squared loss:	0.04905
#   valid loss:		166.79990
#   valid squared loss:	0.04899
# output: not found in network
#   valid loss:		166.79763
#   valid squared loss:	0.04889
# output: not found in network
#   valid loss:		166.61258
#   valid squared loss:	0.04889
# output: not found in network
#   valid loss:		166.26325
#   valid squared loss:	0.04872
# output: not found in network
#   valid loss:		166.41298
#   valid squared loss:	0.04870
#   valid loss:		166.37006
#   valid squared loss:	0.04868
#   valid loss:		166.23980
#   valid squared loss:	0.04869
# output: not found in network
#   valid loss:		166.14195
#   valid squared loss:	0.04858
# output: not found in network
#   valid loss:		165.90776
#   valid squared loss:	0.04850
# output: not found in network
#   valid loss:		165.91648
#   valid squared loss:	0.04855
#   valid loss:		165.95233
#   valid squared loss:	0.04845
#   valid loss:		165.82518
#   valid squared loss:	0.04853
# output: not found in network
#   valid loss:		165.58180
#   valid squared loss:	0.04842
# output: not found in network
#   valid loss:		165.30103
#   valid squared loss:	0.04823
# output: not found in network
#   valid loss:		165.29401
#   valid squared loss:	0.04828
# output: not found in network
#   valid loss:		165.24117
#   valid squared loss:	0.04827
# output: not found in network
#   valid loss:		165.19382
#   valid squared loss:	0.04813
# output: not found in network
#   valid loss:		165.13438
#   valid squared loss:	0.04815
# output: not found in network
#   valid loss:		165.27795
#   valid squared loss:	0.04831
#   valid loss:		165.05664
#   valid squared loss:	0.04809
# output: not found in network
#   valid loss:		164.97029
#   valid squared loss:	0.04809
# output: not found in network
#   valid loss:		164.91815
#   valid squared loss:	0.04804
# output: not found in network
#   valid loss:		164.90846
#   valid squared loss:	0.04812
# output: not found in network
#   valid loss:		164.69698
#   valid squared loss:	0.04790
# output: not found in network
#   valid loss:		164.78796
#   valid squared loss:	0.04798
#   valid loss:		164.49751
#   valid squared loss:	0.04786
# output: not found in network
#   valid loss:		164.39397
#   valid squared loss:	0.04787
# output: not found in network
#   valid loss:		164.46817
#   valid squared loss:	0.04795
#   valid loss:		164.64822
#   valid squared loss:	0.04792
#   valid loss:		164.11972
#   valid squared loss:	0.04773
# output: not found in network
#   valid loss:		164.00610
#   valid squared loss:	0.04768
# output: not found in network
#   valid loss:		163.96601
#   valid squared loss:	0.04767
# output: not found in network
#   valid loss:		163.70746
#   valid squared loss:	0.04750
# output: not found in network
#   valid loss:		163.56308
#   valid squared loss:	0.04749
# output: not found in network
#   valid loss:		163.50886
#   valid squared loss:	0.04736
# output: not found in network
#   valid loss:		163.54320
#   valid squared loss:	0.04743
#   valid loss:		163.44765
#   valid squared loss:	0.04735
# output: not found in network
#   valid loss:		163.38030
#   valid squared loss:	0.04727
# output: not found in network
#   valid loss:		163.34301
#   valid squared loss:	0.04731
# output: not found in network
#   valid loss:		163.17195
#   valid squared loss:	0.04727
# output: not found in network
#   valid loss:		163.16345
#   valid squared loss:	0.04726
# output: not found in network
#   valid loss:		163.19448
#   valid squared loss:	0.04726
#   valid loss:		163.27419
#   valid squared loss:	0.04736
#   valid loss:		163.03015
#   valid squared loss:	0.04719
# output: not found in network
#   valid loss:		162.86255
#   valid squared loss:	0.04703
# output: not found in network
#   valid loss:		163.02370
#   valid squared loss:	0.04719
#   valid loss:		162.74022
#   valid squared loss:	0.04705
# output: not found in network
#   valid loss:		162.78974
#   valid squared loss:	0.04704
#   valid loss:		162.79025
#   valid squared loss:	0.04705
#   valid loss:		162.87723
#   valid squared loss:	0.04706
#   valid loss:		162.61138
#   valid squared loss:	0.04692
# output: not found in network
#   valid loss:		162.55189
#   valid squared loss:	0.04699
# output: not found in network
#   valid loss:		162.74376
#   valid squared loss:	0.04705
#   valid loss:		162.29690
#   valid squared loss:	0.04678
# output: not found in network
#   valid loss:		162.40538
#   valid squared loss:	0.04688
#   valid loss:		162.38395
#   valid squared loss:	0.04677
#   valid loss:		162.27324
#   valid squared loss:	0.04674
# output: not found in network
#   valid loss:		162.08378
#   valid squared loss:	0.04676
# output: not found in network
#   valid loss:		162.30036
#   valid squared loss:	0.04671
#   valid loss:		161.92750
#   valid squared loss:	0.04664
# output: not found in network
#   valid loss:		162.00686
#   valid squared loss:	0.04669
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-15013e1159c2> in <module>()
#       1 # train model
#       2 learn.train_minibatch(nntrainer, data={'train': X_train, 'valid': X_val},
# ----> 3                               batch_size=100, num_epochs=500, patience=50, verbose=0)
#
# /Users/juliankimura/Google Drive/lasagne/theanomics/theanomics/learn.py in train_minibatch(nntrainer, data, batch_size, num_epochs, patience, verbose, shuffle)
#      33                 # test current model with cross-validation data and store results
#      34                 if 'valid' in data.keys():
# ---> 35                         valid_loss = nntrainer.test_model(data['valid'], "valid", batch_size)
#      36
#      37                 # save model
#
# /Users/juliankimura/Google Drive/lasagne/theanomics/theanomics/neuralnetwork.py in test_model(self, test, name, batch_size, verbose)
#     295                 """perform a complete forward pass, store and print results"""
#     296
# --> 297                 test_loss, test_prediction, test_label = self.test_step(test, batch_size)
#     298                 if name == "train":
#     299                         self.train_monitor.update(test_loss, test_prediction, test_label)
#
# /Users/juliankimura/Google Drive/lasagne/theanomics/theanomics/neuralnetwork.py in test_step(self, test, batch_size)
#     282                 for i in range(num_batches):
#     283                         X = next(batches)
# --> 284                         loss, prediction_minibatch = self.test_fun(*X)
#     285                         performance.add_loss(loss)
#     286                         prediction.append(prediction_minibatch)
#
# /Users/juliankimura/anaconda/lib/python3.5/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     882         try:
#     883             outputs =\
# --> 884                 self.fn() if output_subset is None else\
#     885                 self.fn(output_subset=output_subset)
#     886         except Exception:
#
# KeyboardInterrupt:

# %%
num_steps = 10
samples = X_train[:num_steps*num_steps,:]
fig = plt.figure()
plt.imshow((samples.reshape(num_steps, num_steps, 28, 28)
                   .transpose(0, 2, 1, 3)
                   .reshape(num_steps*28, num_steps*28)), cmap='gray')
plt.axis('off')
fig.set_size_inches(10,10)
# Out:
# /Users/juliankimura/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
generated_x = layers.get_output(nnmodel.network['X'], deterministic=True)
gen_fn = theano.function([nnmodel.placeholders['inputs']], generated_x)
num_grid = 10
k = 0
reconstructed_samples = []
for i in range(num_grid):
    for j in range(num_grid):
        reconstructed_samples.append(gen_fn(np.expand_dims(samples[k], axis=0)))
        k += 1
reconstructed_samples = np.array(reconstructed_samples)        

               
fig = plt.figure()
plt.imshow((reconstructed_samples.reshape(num_grid, num_grid, 28, 28)
                   .transpose(0, 2, 1, 3)
                   .reshape(num_grid*28, num_grid*28)), cmap='gray')
plt.axis('off')
fig.set_size_inches(10,10)
# Out:
# /Users/juliankimura/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

z_var = T.dmatrix()
generated_x = layers.get_output(network['dense_4_bias'], {network['Z']: z_var}, deterministic=True)
gen_fn = theano.function([z_var], generated_x)
num_grid = 20
pos = np.linspace(-2, 2, num_grid)
z = []
for i in range(num_grid):
    for j in range(num_grid):
        z.append(np.asarray([pos[i], pos[j]], dtype=theano.config.floatX))
z = np.vstack(z)
generated_samples = sigmoid(gen_fn(z))

     
    
fig = plt.figure()
plt.imshow((generated_samples.reshape(num_grid, num_grid, 28, 28)
                   .transpose(0, 2, 1, 3)
                   .reshape(num_grid*28, num_grid*28)), cmap='gray')
plt.axis('off')
fig.set_size_inches(10,10)
# Out:
# /Users/juliankimura/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
