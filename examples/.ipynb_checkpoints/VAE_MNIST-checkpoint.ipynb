# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
# %matplotlib inline

sys.path.append('/Users/juliankimura/Desktop/deepomics')
import deepomics.neuralnetwork as nn
from deepomics import learn, utils
from models import vae_model

import theano
import theano.tensor as T
from lasagne import layers

np.random.seed(247)   # for reproducibility

# %%
def load_dataset(data_path):
    import gzip
    def load_mnist_images(filename):
        with gzip.open(filename, 'rb') as f:
            data = np.frombuffer(f.read(), np.uint8, offset=16)
        data = data.reshape(-1, 28*28)
        return data / np.float32(256)

    def load_mnist_labels(filename):
        with gzip.open(filename, 'rb') as f:
            data = np.frombuffer(f.read(), np.uint8, offset=8)
        return data

    # We can now download and read the training and test set images and labels.
    X_train = load_mnist_images(os.path.join(data_path,'train-images-idx3-ubyte.gz'))
    y_train = load_mnist_labels(os.path.join(data_path,'train-labels-idx1-ubyte.gz'))
    X_test = load_mnist_images(os.path.join(data_path,'t10k-images-idx3-ubyte.gz'))
    y_test = load_mnist_labels(os.path.join(data_path,'t10k-labels-idx1-ubyte.gz'))

    # We reserve the last 10000 training examples for validation.
    X_train, X_val = X_train[:-10000], X_train[-10000:]
    y_train, y_val = y_train[:-10000], y_train[-10000:]

    # We just return all the arrays in order, as expected in main().
    # (It doesn't matter how we do this as long as we can read them again.)
    return X_train, y_train, X_val, y_val, X_test, y_test


data_path = '/Users/juliankimura/Desktop/data/MNIST'
X_train, y_train, X_val, y_val, X_test, y_test = load_dataset(data_path)

# %%
shape = (None, X_train.shape[1])
network, placeholders, optimization = vae_model.model(shape)

# %%
# build neural network class
nnmodel = nn.NeuralNet(network, placeholders)
nnmodel.inspect_layers()

# set output file paths
output_name = 'MNIST_vae'
results_path = utils.make_directory(data_path, 'Results')
results_path = utils.make_directory(results_path, output_name)
file_path = os.path.join(results_path, output_name)
nntrainer = nn.NeuralTrainer(nnmodel, optimization, save='best', file_path=file_path)
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1:
# <lasagne.layers.input.InputLayer object at 0x11a7ba9e8>
# shape:(None, 784)
# layer2:
# <lasagne.layers.dense.DenseLayer object at 0x11a7bae48>
# shape:(None, 200)
# parameters: W, b
# layer3:
# <lasagne.layers.dense.DenseLayer object at 0x105b7e438>
# shape:(None, 100)
# parameters: W, b
# layer4:
# <lasagne.layers.dense.DenseLayer object at 0x11a7a1470>
# shape:(None, 2)
# parameters: W, b
# layer5:
# <lasagne.layers.dense.DenseLayer object at 0x11a7a1828>
# shape:(None, 2)
# parameters: W, b
# layer6:
# <models.vae_model.VariationalSampleLayer object at 0x105b7e198>
# shape:(None, 2)
# layer7:
# <lasagne.layers.dense.DenseLayer object at 0x11a7a1da0>
# shape:(None, 100)
# parameters: W, b
# layer8:
# <lasagne.layers.dense.DenseLayer object at 0x11a7a1d68>
# shape:(None, 200)
# parameters: W, b
# layer9:
# <lasagne.layers.dense.DenseLayer object at 0x105b722b0>
# shape:(None, 784)
# parameters: W, b
# ----------------------------------------------------------------------------
# compiling model
# True

# %%
# train model
learn.train_minibatch(nntrainer, data={'train': X_train, 'valid': X_val}, 
                              batch_size=100, num_epochs=500, patience=10, verbose=0)
# Out:
#   valid loss:		525.08398
#   valid squared loss:	0.21679
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		477.13197
#   valid squared loss:	0.18031
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		404.12451
#   valid squared loss:	0.13074
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		340.13735
#   valid squared loss:	0.10233
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		296.38624
#   valid squared loss:	0.08709
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		269.32088
#   valid squared loss:	0.07866
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		252.34247
#   valid squared loss:	0.07396
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		239.23376
#   valid squared loss:	0.07156
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		229.03745
#   valid squared loss:	0.06936
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		222.13708
#   valid squared loss:	0.06781
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		217.70099
#   valid squared loss:	0.06708
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		214.52251
#   valid squared loss:	0.06628
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		212.42658
#   valid squared loss:	0.06578
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		210.32481
#   valid squared loss:	0.06533
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		208.85332
#   valid squared loss:	0.06515
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		207.86235
#   valid squared loss:	0.06499
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		206.94312
#   valid squared loss:	0.06489
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		205.82797
#   valid squared loss:	0.06461
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		205.34370
#   valid squared loss:	0.06448
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		204.48838
#   valid squared loss:	0.06434
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		204.14452
#   valid squared loss:	0.06436
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		203.57292
#   valid squared loss:	0.06414
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		203.27023
#   valid squared loss:	0.06404
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		202.86378
#   valid squared loss:	0.06408
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		202.43599
#   valid squared loss:	0.06394
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		202.15716
#   valid squared loss:	0.06381
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		201.87029
#   valid squared loss:	0.06382
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		201.71547
#   valid squared loss:	0.06355
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		201.33482
#   valid squared loss:	0.06367
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		201.16864
#   valid squared loss:	0.06373
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		200.82717
#   valid squared loss:	0.06336
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		200.56000
#   valid squared loss:	0.06347
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		200.42426
#   valid squared loss:	0.06336
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		200.05962
#   valid squared loss:	0.06331
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		199.86575
#   valid squared loss:	0.06322
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		199.58617
#   valid squared loss:	0.06311
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		199.26626
#   valid squared loss:	0.06300
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		198.89948
#   valid squared loss:	0.06272
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		198.39908
#   valid squared loss:	0.06250
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		198.03723
#   valid squared loss:	0.06233
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		197.55068
#   valid squared loss:	0.06209
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		196.96795
#   valid squared loss:	0.06169
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		196.32481
#   valid squared loss:	0.06135
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		195.45542
#   valid squared loss:	0.06078
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		194.94686
#   valid squared loss:	0.06051
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		194.30870
#   valid squared loss:	0.06027
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		193.72131
#   valid squared loss:	0.05993
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		193.07591
#   valid squared loss:	0.05964
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		192.74951
#   valid squared loss:	0.05959
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		192.33822
#   valid squared loss:	0.05943
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		192.08355
#   valid squared loss:	0.05924
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		191.78750
#   valid squared loss:	0.05918
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		191.51087
#   valid squared loss:	0.05908
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		191.21770
#   valid squared loss:	0.05904
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		190.82782
#   valid squared loss:	0.05881
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		190.66800
#   valid squared loss:	0.05880
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		190.73803
#   valid squared loss:	0.05889
#
#   valid loss:		190.17490
#   valid squared loss:	0.05860
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		189.99074
#   valid squared loss:	0.05857
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		189.88249
#   valid squared loss:	0.05848
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		189.61262
#   valid squared loss:	0.05847
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		189.80524
#   valid squared loss:	0.05845
#
#   valid loss:		189.33910
#   valid squared loss:	0.05830
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		189.19478
#   valid squared loss:	0.05830
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		189.06712
#   valid squared loss:	0.05834
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		188.91797
#   valid squared loss:	0.05829
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		188.68586
#   valid squared loss:	0.05822
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		188.49984
#   valid squared loss:	0.05801
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		188.52712
#   valid squared loss:	0.05803
#
#   valid loss:		188.36620
#   valid squared loss:	0.05803
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		188.15789
#   valid squared loss:	0.05802
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		188.00270
#   valid squared loss:	0.05792
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		187.86766
#   valid squared loss:	0.05787
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		187.83857
#   valid squared loss:	0.05798
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		187.80407
#   valid squared loss:	0.05800
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		187.34994
#   valid squared loss:	0.05774
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		187.15886
#   valid squared loss:	0.05768
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		187.10121
#   valid squared loss:	0.05763
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		186.71851
#   valid squared loss:	0.05745
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		186.64591
#   valid squared loss:	0.05738
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		186.33464
#   valid squared loss:	0.05738
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		186.21396
#   valid squared loss:	0.05732
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		185.93419
#   valid squared loss:	0.05710
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		185.63554
#   valid squared loss:	0.05704
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		185.35336
#   valid squared loss:	0.05699
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		185.05734
#   valid squared loss:	0.05693
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		184.78685
#   valid squared loss:	0.05675
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		184.48954
#   valid squared loss:	0.05652
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		184.10995
#   valid squared loss:	0.05643
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		183.82141
#   valid squared loss:	0.05640
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		183.48201
#   valid squared loss:	0.05622
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		183.20208
#   valid squared loss:	0.05618
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		182.75990
#   valid squared loss:	0.05589
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		182.40928
#   valid squared loss:	0.05578
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		182.42733
#   valid squared loss:	0.05591
#
#   valid loss:		181.96813
#   valid squared loss:	0.05563
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		181.52442
#   valid squared loss:	0.05546
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		181.41936
#   valid squared loss:	0.05541
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		181.04966
#   valid squared loss:	0.05532
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		180.85367
#   valid squared loss:	0.05519
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		180.66522
#   valid squared loss:	0.05510
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		180.49191
#   valid squared loss:	0.05509
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		180.36344
#   valid squared loss:	0.05499
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		180.13119
#   valid squared loss:	0.05486
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		180.07775
#   valid squared loss:	0.05492
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		179.91709
#   valid squared loss:	0.05489
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		179.62659
#   valid squared loss:	0.05472
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		179.63330
#   valid squared loss:	0.05475
#
#   valid loss:		179.25776
#   valid squared loss:	0.05450
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		179.08024
#   valid squared loss:	0.05446
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		178.98247
#   valid squared loss:	0.05446
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		179.04990
#   valid squared loss:	0.05452
#
#   valid loss:		178.79100
#   valid squared loss:	0.05439
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		178.62743
#   valid squared loss:	0.05432
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		178.59113
#   valid squared loss:	0.05428
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		178.40039
#   valid squared loss:	0.05420
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		178.24793
#   valid squared loss:	0.05410
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		178.11536
#   valid squared loss:	0.05404
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		177.96188
#   valid squared loss:	0.05410
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		177.93688
#   valid squared loss:	0.05410
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		177.85127
#   valid squared loss:	0.05399
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		177.75109
#   valid squared loss:	0.05393
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		177.57678
#   valid squared loss:	0.05389
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		177.42290
#   valid squared loss:	0.05381
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		177.33163
#   valid squared loss:	0.05375
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		177.28986
#   valid squared loss:	0.05381
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		177.15833
#   valid squared loss:	0.05364
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		177.03005
#   valid squared loss:	0.05356
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		176.98119
#   valid squared loss:	0.05362
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		176.88515
#   valid squared loss:	0.05362
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		176.78379
#   valid squared loss:	0.05348
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		176.59585
#   valid squared loss:	0.05346
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		176.57747
#   valid squared loss:	0.05345
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		176.46683
#   valid squared loss:	0.05339
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		176.29435
#   valid squared loss:	0.05324
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		176.15931
#   valid squared loss:	0.05325
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		176.24163
#   valid squared loss:	0.05334
#
#   valid loss:		175.96634
#   valid squared loss:	0.05315
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		175.91966
#   valid squared loss:	0.05314
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		175.92719
#   valid squared loss:	0.05312
#
#   valid loss:		175.95391
#   valid squared loss:	0.05318
#
#   valid loss:		175.65404
#   valid squared loss:	0.05305
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		175.63682
#   valid squared loss:	0.05298
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		175.48619
#   valid squared loss:	0.05289
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		175.55630
#   valid squared loss:	0.05303
#
#   valid loss:		175.26712
#   valid squared loss:	0.05281
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		175.39066
#   valid squared loss:	0.05288
#
#   valid loss:		175.30078
#   valid squared loss:	0.05293
#
#   valid loss:		175.08149
#   valid squared loss:	0.05277
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		175.08610
#   valid squared loss:	0.05272
#
#   valid loss:		174.92881
#   valid squared loss:	0.05269
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		174.97004
#   valid squared loss:	0.05273
#
#   valid loss:		174.94476
#   valid squared loss:	0.05273
#
#   valid loss:		174.68107
#   valid squared loss:	0.05257
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		174.74123
#   valid squared loss:	0.05253
#
#   valid loss:		174.60839
#   valid squared loss:	0.05243
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		174.51869
#   valid squared loss:	0.05248
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		174.41228
#   valid squared loss:	0.05242
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		174.30245
#   valid squared loss:	0.05234
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		174.28431
#   valid squared loss:	0.05233
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		174.21031
#   valid squared loss:	0.05230
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		174.15562
#   valid squared loss:	0.05222
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		173.94871
#   valid squared loss:	0.05222
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		173.82538
#   valid squared loss:	0.05212
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		173.92295
#   valid squared loss:	0.05223
#
#   valid loss:		173.76519
#   valid squared loss:	0.05207
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		173.62868
#   valid squared loss:	0.05206
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		173.59487
#   valid squared loss:	0.05201
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		173.47737
#   valid squared loss:	0.05190
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		173.44296
#   valid squared loss:	0.05194
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		173.42360
#   valid squared loss:	0.05196
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		173.24207
#   valid squared loss:	0.05182
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		173.20217
#   valid squared loss:	0.05181
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		172.94646
#   valid squared loss:	0.05172
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		172.97440
#   valid squared loss:	0.05167
#
#   valid loss:		172.81366
#   valid squared loss:	0.05157
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		172.68724
#   valid squared loss:	0.05157
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		172.62794
#   valid squared loss:	0.05163
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		172.62084
#   valid squared loss:	0.05150
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		172.40189
#   valid squared loss:	0.05135
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		172.23502
#   valid squared loss:	0.05134
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		172.17319
#   valid squared loss:	0.05134
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		172.20051
#   valid squared loss:	0.05138
#
#   valid loss:		172.33458
#   valid squared loss:	0.05130
#
#   valid loss:		172.04114
#   valid squared loss:	0.05128
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		171.94201
#   valid squared loss:	0.05112
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		171.79782
#   valid squared loss:	0.05116
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		171.74624
#   valid squared loss:	0.05108
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		171.51123
#   valid squared loss:	0.05097
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		171.39896
#   valid squared loss:	0.05089
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		171.33659
#   valid squared loss:	0.05085
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		171.40410
#   valid squared loss:	0.05082
#
#   valid loss:		171.20198
#   valid squared loss:	0.05088
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		171.18063
#   valid squared loss:	0.05079
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		171.04486
#   valid squared loss:	0.05071
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.95772
#   valid squared loss:	0.05063
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.79874
#   valid squared loss:	0.05056
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.71092
#   valid squared loss:	0.05060
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.90655
#   valid squared loss:	0.05063
#
#   valid loss:		170.66558
#   valid squared loss:	0.05049
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.57909
#   valid squared loss:	0.05040
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.49791
#   valid squared loss:	0.05042
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.46571
#   valid squared loss:	0.05038
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.41367
#   valid squared loss:	0.05048
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.35355
#   valid squared loss:	0.05035
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.17328
#   valid squared loss:	0.05025
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.17098
#   valid squared loss:	0.05023
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.01288
#   valid squared loss:	0.05035
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		170.17469
#   valid squared loss:	0.05031
#
#   valid loss:		170.06723
#   valid squared loss:	0.05029
#
#   valid loss:		169.99363
#   valid squared loss:	0.05018
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		169.79050
#   valid squared loss:	0.05011
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		169.65416
#   valid squared loss:	0.04999
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		169.72266
#   valid squared loss:	0.05013
#
#   valid loss:		169.77259
#   valid squared loss:	0.05003
#
#   valid loss:		169.51482
#   valid squared loss:	0.04991
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		169.45416
#   valid squared loss:	0.04992
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		169.40361
#   valid squared loss:	0.05000
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		169.39979
#   valid squared loss:	0.04990
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		169.34858
#   valid squared loss:	0.04997
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		169.27237
#   valid squared loss:	0.04988
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		169.29210
#   valid squared loss:	0.04989
#
#   valid loss:		169.02990
#   valid squared loss:	0.04972
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		169.07307
#   valid squared loss:	0.04979
#
#   valid loss:		169.13483
#   valid squared loss:	0.04984
#
#   valid loss:		169.04486
#   valid squared loss:	0.04979
#
#   valid loss:		169.05206
#   valid squared loss:	0.04981
#
#   valid loss:		169.11111
#   valid squared loss:	0.04979
#
#   valid loss:		168.85937
#   valid squared loss:	0.04971
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		168.83542
#   valid squared loss:	0.04962
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		168.87305
#   valid squared loss:	0.04973
#
#   valid loss:		168.70338
#   valid squared loss:	0.04959
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		168.63108
#   valid squared loss:	0.04960
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		168.79440
#   valid squared loss:	0.04947
#
#   valid loss:		168.64788
#   valid squared loss:	0.04964
#
#   valid loss:		168.53682
#   valid squared loss:	0.04954
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		168.37446
#   valid squared loss:	0.04951
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		168.38913
#   valid squared loss:	0.04946
#
#   valid loss:		168.43576
#   valid squared loss:	0.04953
#
#   valid loss:		168.40413
#   valid squared loss:	0.04952
#
#   valid loss:		168.25169
#   valid squared loss:	0.04940
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		168.19098
#   valid squared loss:	0.04932
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		168.45236
#   valid squared loss:	0.04959
#
#   valid loss:		168.22518
#   valid squared loss:	0.04951
#
#   valid loss:		168.11853
#   valid squared loss:	0.04941
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		168.07408
#   valid squared loss:	0.04938
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		168.22270
#   valid squared loss:	0.04938
#
#   valid loss:		168.14536
#   valid squared loss:	0.04940
#
#   valid loss:		168.21139
#   valid squared loss:	0.04928
#
#   valid loss:		168.15582
#   valid squared loss:	0.04951
#
#   valid loss:		168.17766
#   valid squared loss:	0.04936
#
#   valid loss:		167.85007
#   valid squared loss:	0.04933
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.86129
#   valid squared loss:	0.04920
#
#   valid loss:		167.87202
#   valid squared loss:	0.04917
#
#   valid loss:		167.92072
#   valid squared loss:	0.04928
#
#   valid loss:		167.79490
#   valid squared loss:	0.04918
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.79206
#   valid squared loss:	0.04927
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.87236
#   valid squared loss:	0.04914
#
#   valid loss:		167.77439
#   valid squared loss:	0.04939
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.61713
#   valid squared loss:	0.04923
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.61777
#   valid squared loss:	0.04925
#
#   valid loss:		167.64982
#   valid squared loss:	0.04916
#
#   valid loss:		167.54750
#   valid squared loss:	0.04907
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.55787
#   valid squared loss:	0.04907
#
#   valid loss:		167.31748
#   valid squared loss:	0.04900
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.37850
#   valid squared loss:	0.04893
#
#   valid loss:		167.41928
#   valid squared loss:	0.04900
#
#   valid loss:		167.26762
#   valid squared loss:	0.04901
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.32129
#   valid squared loss:	0.04898
#
#   valid loss:		167.29934
#   valid squared loss:	0.04898
#
#   valid loss:		167.27499
#   valid squared loss:	0.04898
#
#   valid loss:		167.19735
#   valid squared loss:	0.04905
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.07665
#   valid squared loss:	0.04880
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.05617
#   valid squared loss:	0.04889
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		167.08251
#   valid squared loss:	0.04888
#
#   valid loss:		167.17833
#   valid squared loss:	0.04898
#
#   valid loss:		166.98728
#   valid squared loss:	0.04882
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		166.85067
#   valid squared loss:	0.04884
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		166.77520
#   valid squared loss:	0.04873
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		166.86914
#   valid squared loss:	0.04886
#
#   valid loss:		166.84122
#   valid squared loss:	0.04879
#
#   valid loss:		166.88092
#   valid squared loss:	0.04883
#
#   valid loss:		166.69346
#   valid squared loss:	0.04870
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		166.86120
#   valid squared loss:	0.04878
#
#   valid loss:		166.57634
#   valid squared loss:	0.04868
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		166.68172
#   valid squared loss:	0.04877
#
#   valid loss:		166.52102
#   valid squared loss:	0.04871
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		166.58303
#   valid squared loss:	0.04862
#
#   valid loss:		166.52188
#   valid squared loss:	0.04873
#
#   valid loss:		166.44555
#   valid squared loss:	0.04870
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		166.57325
#   valid squared loss:	0.04869
#
#   valid loss:		166.30889
#   valid squared loss:	0.04861
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		166.21915
#   valid squared loss:	0.04858
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		166.42102
#   valid squared loss:	0.04873
#
#   valid loss:		166.29542
#   valid squared loss:	0.04855
#
#   valid loss:		166.37305
#   valid squared loss:	0.04857
#
#   valid loss:		166.25519
#   valid squared loss:	0.04856
#
#   valid loss:		166.22820
#   valid squared loss:	0.04844
#
#   valid loss:		166.22011
#   valid squared loss:	0.04853
#
#   valid loss:		166.13134
#   valid squared loss:	0.04844
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.98138
#   valid squared loss:	0.04837
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		166.16057
#   valid squared loss:	0.04851
#
#   valid loss:		166.03067
#   valid squared loss:	0.04841
#
#   valid loss:		166.09197
#   valid squared loss:	0.04853
#
#   valid loss:		166.31373
#   valid squared loss:	0.04845
#
#   valid loss:		166.17390
#   valid squared loss:	0.04860
#
#   valid loss:		165.96675
#   valid squared loss:	0.04836
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.81889
#   valid squared loss:	0.04834
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.81231
#   valid squared loss:	0.04836
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.82863
#   valid squared loss:	0.04832
#
#   valid loss:		165.77670
#   valid squared loss:	0.04835
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.79731
#   valid squared loss:	0.04833
#
#   valid loss:		165.73381
#   valid squared loss:	0.04831
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.76127
#   valid squared loss:	0.04832
#
#   valid loss:		165.67028
#   valid squared loss:	0.04830
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.49339
#   valid squared loss:	0.04817
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.47285
#   valid squared loss:	0.04816
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.52644
#   valid squared loss:	0.04816
#
#   valid loss:		165.46431
#   valid squared loss:	0.04819
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.37617
#   valid squared loss:	0.04817
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.35918
#   valid squared loss:	0.04809
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.34323
#   valid squared loss:	0.04806
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.32097
#   valid squared loss:	0.04815
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.30244
#   valid squared loss:	0.04808
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.39190
#   valid squared loss:	0.04817
#
#   valid loss:		165.35325
#   valid squared loss:	0.04808
#
#   valid loss:		165.24989
#   valid squared loss:	0.04812
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.29202
#   valid squared loss:	0.04810
#
#   valid loss:		165.07721
#   valid squared loss:	0.04799
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.09862
#   valid squared loss:	0.04793
#
#   valid loss:		165.09412
#   valid squared loss:	0.04805
#
#   valid loss:		165.06056
#   valid squared loss:	0.04797
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		165.00378
#   valid squared loss:	0.04796
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.82911
#   valid squared loss:	0.04787
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.81093
#   valid squared loss:	0.04784
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.80039
#   valid squared loss:	0.04788
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.88155
#   valid squared loss:	0.04785
#
#   valid loss:		164.91466
#   valid squared loss:	0.04791
#
#   valid loss:		164.87408
#   valid squared loss:	0.04790
#
#   valid loss:		165.00377
#   valid squared loss:	0.04795
#
#   valid loss:		164.87734
#   valid squared loss:	0.04786
#
#   valid loss:		164.67576
#   valid squared loss:	0.04783
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.94467
#   valid squared loss:	0.04795
#
#   valid loss:		164.76292
#   valid squared loss:	0.04791
#
#   valid loss:		164.59353
#   valid squared loss:	0.04782
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.63941
#   valid squared loss:	0.04782
#
#   valid loss:		164.63122
#   valid squared loss:	0.04775
#
#   valid loss:		164.67563
#   valid squared loss:	0.04783
#
#   valid loss:		164.62782
#   valid squared loss:	0.04782
#
#   valid loss:		164.59529
#   valid squared loss:	0.04783
#
#   valid loss:		164.72195
#   valid squared loss:	0.04781
#
#   valid loss:		164.46834
#   valid squared loss:	0.04766
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.56382
#   valid squared loss:	0.04780
#
#   valid loss:		164.39217
#   valid squared loss:	0.04779
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.29017
#   valid squared loss:	0.04757
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.23047
#   valid squared loss:	0.04758
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.19235
#   valid squared loss:	0.04760
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.21931
#   valid squared loss:	0.04772
#
#   valid loss:		164.27753
#   valid squared loss:	0.04761
#
#   valid loss:		164.32531
#   valid squared loss:	0.04765
#
#   valid loss:		164.31027
#   valid squared loss:	0.04766
#
#   valid loss:		164.24987
#   valid squared loss:	0.04766
#
#   valid loss:		164.03648
#   valid squared loss:	0.04755
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		164.11399
#   valid squared loss:	0.04762
#
#   valid loss:		164.07209
#   valid squared loss:	0.04752
#
#   valid loss:		164.21986
#   valid squared loss:	0.04766
#
#   valid loss:		164.06573
#   valid squared loss:	0.04748
#
#   valid loss:		164.00500
#   valid squared loss:	0.04752
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.86833
#   valid squared loss:	0.04742
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.91864
#   valid squared loss:	0.04744
#
#   valid loss:		163.85421
#   valid squared loss:	0.04739
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.99532
#   valid squared loss:	0.04748
#
#   valid loss:		163.93020
#   valid squared loss:	0.04753
#
#   valid loss:		163.86735
#   valid squared loss:	0.04736
#
#   valid loss:		163.76098
#   valid squared loss:	0.04733
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.91536
#   valid squared loss:	0.04752
#
#   valid loss:		163.64217
#   valid squared loss:	0.04731
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.70399
#   valid squared loss:	0.04734
#
#   valid loss:		163.73457
#   valid squared loss:	0.04740
#
#   valid loss:		163.62545
#   valid squared loss:	0.04734
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.53598
#   valid squared loss:	0.04727
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.59468
#   valid squared loss:	0.04724
#
#   valid loss:		163.65203
#   valid squared loss:	0.04727
#
#   valid loss:		163.72614
#   valid squared loss:	0.04744
#
#   valid loss:		163.60930
#   valid squared loss:	0.04735
#
#   valid loss:		163.60836
#   valid squared loss:	0.04728
#
#   valid loss:		163.53572
#   valid squared loss:	0.04714
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.52535
#   valid squared loss:	0.04720
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.48076
#   valid squared loss:	0.04721
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.46958
#   valid squared loss:	0.04724
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.41223
#   valid squared loss:	0.04715
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.49329
#   valid squared loss:	0.04720
#
#   valid loss:		163.52610
#   valid squared loss:	0.04740
#
#   valid loss:		163.42270
#   valid squared loss:	0.04723
#
#   valid loss:		163.39785
#   valid squared loss:	0.04719
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.37485
#   valid squared loss:	0.04716
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.33255
#   valid squared loss:	0.04716
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.29537
#   valid squared loss:	0.04716
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.50943
#   valid squared loss:	0.04734
#
#   valid loss:		163.40069
#   valid squared loss:	0.04720
#
#   valid loss:		163.14330
#   valid squared loss:	0.04700
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.18861
#   valid squared loss:	0.04709
#
#   valid loss:		163.16571
#   valid squared loss:	0.04712
#
#   valid loss:		163.02911
#   valid squared loss:	0.04706
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.04527
#   valid squared loss:	0.04705
#
#   valid loss:		163.04562
#   valid squared loss:	0.04699
#
#   valid loss:		163.03844
#   valid squared loss:	0.04709
#
#   valid loss:		162.87391
#   valid squared loss:	0.04700
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		163.11134
#   valid squared loss:	0.04713
#
#   valid loss:		162.98252
#   valid squared loss:	0.04698
#
#   valid loss:		163.11431
#   valid squared loss:	0.04706
#
#   valid loss:		163.10270
#   valid squared loss:	0.04709
#
#   valid loss:		162.88221
#   valid squared loss:	0.04694
#
#   valid loss:		162.91502
#   valid squared loss:	0.04689
#
#   valid loss:		162.95166
#   valid squared loss:	0.04698
#
#   valid loss:		162.92977
#   valid squared loss:	0.04705
#
#   valid loss:		162.94946
#   valid squared loss:	0.04692
#
#   valid loss:		162.86626
#   valid squared loss:	0.04698
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.66053
#   valid squared loss:	0.04676
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.87279
#   valid squared loss:	0.04688
#
#   valid loss:		162.59885
#   valid squared loss:	0.04689
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.74924
#   valid squared loss:	0.04688
#
#   valid loss:		162.63881
#   valid squared loss:	0.04676
#
#   valid loss:		162.80702
#   valid squared loss:	0.04691
#
#   valid loss:		162.82612
#   valid squared loss:	0.04698
#
#   valid loss:		162.76273
#   valid squared loss:	0.04693
#
#   valid loss:		162.60940
#   valid squared loss:	0.04681
#
#   valid loss:		162.59487
#   valid squared loss:	0.04683
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.73787
#   valid squared loss:	0.04686
#
#   valid loss:		162.71079
#   valid squared loss:	0.04682
#
#   valid loss:		162.46745
#   valid squared loss:	0.04672
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.44911
#   valid squared loss:	0.04679
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.30288
#   valid squared loss:	0.04664
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.46339
#   valid squared loss:	0.04680
#
#   valid loss:		162.28916
#   valid squared loss:	0.04665
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.18932
#   valid squared loss:	0.04654
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.21499
#   valid squared loss:	0.04662
#
#   valid loss:		162.53278
#   valid squared loss:	0.04680
#
#   valid loss:		162.41231
#   valid squared loss:	0.04674
#
#   valid loss:		162.48422
#   valid squared loss:	0.04671
#
#   valid loss:		162.27840
#   valid squared loss:	0.04668
#
#   valid loss:		162.28612
#   valid squared loss:	0.04656
#
#   valid loss:		162.30862
#   valid squared loss:	0.04666
#
#   valid loss:		162.29762
#   valid squared loss:	0.04671
#
#   valid loss:		162.27734
#   valid squared loss:	0.04662
#
#   valid loss:		162.03987
#   valid squared loss:	0.04653
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.12273
#   valid squared loss:	0.04652
#
#   valid loss:		162.08722
#   valid squared loss:	0.04654
#
#   valid loss:		162.02230
#   valid squared loss:	0.04656
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		161.98165
#   valid squared loss:	0.04647
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		162.07214
#   valid squared loss:	0.04661
#
#   valid loss:		162.04555
#   valid squared loss:	0.04651
#
#   valid loss:		162.04704
#   valid squared loss:	0.04658
#
#   valid loss:		161.87277
#   valid squared loss:	0.04651
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		161.90650
#   valid squared loss:	0.04648
#
#   valid loss:		162.00500
#   valid squared loss:	0.04659
#
#   valid loss:		161.96091
#   valid squared loss:	0.04654
#
#   valid loss:		161.79753
#   valid squared loss:	0.04651
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		161.75893
#   valid squared loss:	0.04643
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		161.64720
#   valid squared loss:	0.04643
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		161.77283
#   valid squared loss:	0.04646
#
#   valid loss:		161.75807
#   valid squared loss:	0.04641
#
#   valid loss:		161.81643
#   valid squared loss:	0.04644
#
#   valid loss:		161.69624
#   valid squared loss:	0.04633
#
#   valid loss:		161.76627
#   valid squared loss:	0.04649
#
#   valid loss:		161.78285
#   valid squared loss:	0.04648
#
#   valid loss:		161.58566
#   valid squared loss:	0.04629
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		161.72809
#   valid squared loss:	0.04639
#
#   valid loss:		161.86005
#   valid squared loss:	0.04643
#
#   valid loss:		161.63042
#   valid squared loss:	0.04631
#
#   valid loss:		161.66247
#   valid squared loss:	0.04634
#
#   valid loss:		161.77847
#   valid squared loss:	0.04634
#
#   valid loss:		161.92272
#   valid squared loss:	0.04645
#
#   valid loss:		161.60778
#   valid squared loss:	0.04634
#
#   valid loss:		161.66624
#   valid squared loss:	0.04632
#
#   valid loss:		161.48177
#   valid squared loss:	0.04628
# saving model parameters to: /Users/juliankimura/Desktop/data/MNIST/Results/MNIST_vae/MNIST_vae_best.pickle
#
#   valid loss:		161.51879
#   valid squared loss:	0.04628
#
#   valid loss:		161.60801
#   valid squared loss:	0.04626
#
#   valid loss:		161.61627
#   valid squared loss:	0.04633
#
#   valid loss:		161.64783
#   valid squared loss:	0.04635
#
#   valid loss:		161.51712
#   valid squared loss:	0.04627
#
#   valid loss:		161.62056
#   valid squared loss:	0.04641
#
#   valid loss:		161.56718
#   valid squared loss:	0.04617
#
#   valid loss:		161.57324
#   valid squared loss:	0.04627
#
#   valid loss:		161.64219
#   valid squared loss:	0.04624
#
#   valid loss:		161.53220
#   valid squared loss:	0.04632
# Patience ran out... Early stopping.

# %%
num_steps = 10
samples = X_train[:num_steps*num_steps,:]
fig = plt.figure()
plt.imshow((samples.reshape(num_steps, num_steps, 28, 28)
                   .transpose(0, 2, 1, 3)
                   .reshape(num_steps*28, num_steps*28)), cmap='gray')
plt.axis('off')
fig.set_size_inches(10,10)
# Out:
# /Users/juliankimura/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
generated_x = layers.get_output(nnmodel.network['decode_mu'], deterministic=True)
gen_fn = theano.function([nnmodel.placeholders['inputs']], generated_x)
num_grid = 10
k = 0
reconstructed_samples = []
for i in range(num_grid):
    for j in range(num_grid):
        reconstructed_samples.append(gen_fn(np.expand_dims(samples[k], axis=0)))
        k += 1
reconstructed_samples = np.array(reconstructed_samples)        

               
fig = plt.figure()
plt.imshow((reconstructed_samples.reshape(num_grid, num_grid, 28, 28)
                   .transpose(0, 2, 1, 3)
                   .reshape(num_grid*28, num_grid*28)), cmap='gray')
plt.axis('off')
fig.set_size_inches(10,10)
# Out:
# /Users/juliankimura/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
z_var = T.vector()
generated_x = layers.get_output(nnmodel.network['decode_mu'], {nnmodel.network['encode_mu']: z_var}, deterministic=True)
gen_fn = theano.function([z_var], generated_x)
num_grid = 10
pos = np.linspace(-3, 3, num_grid)
generated_samples = []
for i in range(num_grid):
    for j in range(num_grid):
        z = np.asarray([pos[i], pos[j]], dtype=theano.config.floatX)
        generated_samples.append(gen_fn(z))
generated_samples = np.array(generated_samples)        
                
     
fig = plt.figure()
plt.imshow((generated_samples.reshape(num_grid, num_grid, 28, 28)
                   .transpose(0, 2, 1, 3)
                   .reshape(num_grid*28, num_grid*28)), cmap='gray')
plt.axis('off')
fig.set_size_inches(10,10)
# Out:
# /Users/juliankimura/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
