# %%
import sys
import os
import numpy as np
sys.path.append('..')
from src import NeuralNet
from src import train as fit
from src import make_directory 
from models import load_model
from data import load_data
from six.moves import cPickle
from subprocess import call

np.random.seed(247) # for reproducibility

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib as mpl
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
# %matplotlib inline
from scipy.misc import imresize

from lasagne import layers, nonlinearities, updates, objectives, init 
from lasagne.layers import Conv2DLayer, TransposedConv2DLayer, DenseLayer, InputLayer, ExpressionLayer, BiasLayer

from lasagne.layers import get_output, get_output_shape, get_all_params
import theano.tensor as T
import theano
np.random.seed(247) # for reproducibility
# Out:
# Using gpu device 0: GeForce GTX 980 (CNMeM is disabled, CuDNN 4007)

# %%
filename = 'Unlocalized_N=300000_S=200_M=50_G=20_data.pickle'
datapath = '/home/peter/Data/SequenceMotif'
filepath = os.path.join(datapath, filename)

# load training set
print "loading data from: " + filepath
f = open(filepath, 'rb')
print "loading train data"
train = cPickle.load(f)
print "loading cross-validation data"
cross_validation = cPickle.load(f)
print "loading test data"
test = cPickle.load(f)
f.close()

X_train = train[0].transpose((0,1,2)).astype(np.float32)
y_train = train[1].astype(np.int32)
X_val = cross_validation[0].transpose((0,1,2)).astype(np.float32)
y_val = cross_validation[1].astype(np.int32)
X_test = test[0].transpose((0,1,2)).astype(np.float32)
y_test = test[1].astype(np.int32)

X_train = np.expand_dims(X_train, axis=3)
X_val = np.expand_dims(X_val, axis=3)
X_test = np.expand_dims(X_test, axis=3)

train = (X_train, y_train, train[2])
valid = (X_val, y_val, cross_validation[2])
test = (X_test, y_test, test[2])

shape = (None, train[0].shape[1], train[0].shape[2], train[0].shape[3])
num_labels = train[1].shape[1]
# Out:
# loading data from: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle
# loading train data
# loading cross-validation data
# loading test data

# %%
model_name = "test_motif_model"
nnmodel = NeuralNet(model_name, shape, num_labels)

# %%
nnmodel = fit.train_minibatch(nnmodel, train, valid, batch_size=128, num_epochs=500, 
                        patience=3, verbose=1, filepath=filepath)
# Out:
# Epoch 1 out of 500
# [==============================] 100.0% -- time=0s -- loss=1.28458 -- accuracy=94.24%
#   valid loss:		0.57115
#   valid accuracy:	0.96412+/-0.02504
#   valid auc-roc:	0.89820+/-0.06634
#   valid auc-pr:		0.49131+/-0.28732
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_0.pickle
# Epoch 2 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.40412 -- accuracy=97.09%
#   valid loss:		0.30839
#   valid accuracy:	0.97492+/-0.01837
#   valid auc-roc:	0.95333+/-0.04250
#   valid auc-pr:		0.67644+/-0.26943
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_1.pickle
# Epoch 3 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.26402 -- accuracy=97.78%
#   valid loss:		0.23471
#   valid accuracy:	0.97916+/-0.01598
#   valid auc-roc:	0.96801+/-0.03452
#   valid auc-pr:		0.75050+/-0.24301
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_2.pickle
# Epoch 4 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.21432 -- accuracy=98.03%
#   valid loss:		0.20030
#   valid accuracy:	0.97990+/-0.01560
#   valid auc-roc:	0.97349+/-0.02867
#   valid auc-pr:		0.77859+/-0.23488
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_3.pickle
# Epoch 5 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.18531 -- accuracy=98.15%
#   valid loss:		0.17448
#   valid accuracy:	0.98118+/-0.01543
#   valid auc-roc:	0.97601+/-0.02793
#   valid auc-pr:		0.79383+/-0.23148
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_4.pickle
# Epoch 6 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.16376 -- accuracy=98.21%
#   valid loss:		0.15661
#   valid accuracy:	0.98153+/-0.01544
#   valid auc-roc:	0.97638+/-0.02883
#   valid auc-pr:		0.80576+/-0.23026
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_5.pickle
# Epoch 7 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.14707 -- accuracy=98.26%
#   valid loss:		0.14158
#   valid accuracy:	0.98214+/-0.01462
#   valid auc-roc:	0.97677+/-0.02853
#   valid auc-pr:		0.80934+/-0.22986
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_6.pickle
# Epoch 8 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.13365 -- accuracy=98.29%
#   valid loss:		0.12713
#   valid accuracy:	0.98317+/-0.01430
#   valid auc-roc:	0.97861+/-0.02722
#   valid auc-pr:		0.82003+/-0.22023
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_7.pickle
# Epoch 9 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.12259 -- accuracy=98.33%
#   valid loss:		0.11837
#   valid accuracy:	0.98335+/-0.01393
#   valid auc-roc:	0.97902+/-0.02571
#   valid auc-pr:		0.81975+/-0.22383
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_8.pickle
# Epoch 10 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.11446 -- accuracy=98.37%
#   valid loss:		0.11157
#   valid accuracy:	0.98350+/-0.01386
#   valid auc-roc:	0.97866+/-0.02733
#   valid auc-pr:		0.82224+/-0.22179
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_9.pickle
# Epoch 11 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.10844 -- accuracy=98.39%
#   valid loss:		0.10781
#   valid accuracy:	0.98332+/-0.01436
#   valid auc-roc:	0.97982+/-0.02484
#   valid auc-pr:		0.82241+/-0.22309
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_10.pickle
# Epoch 12 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.10384 -- accuracy=98.41%
#   valid loss:		0.10135
#   valid accuracy:	0.98422+/-0.01360
#   valid auc-roc:	0.98042+/-0.02501
#   valid auc-pr:		0.82906+/-0.22104
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_11.pickle
# Epoch 13 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.10009 -- accuracy=98.42%
#   valid loss:		0.09853
#   valid accuracy:	0.98425+/-0.01372
#   valid auc-roc:	0.98083+/-0.02403
#   valid auc-pr:		0.82810+/-0.22385
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_12.pickle
# Epoch 14 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.09706 -- accuracy=98.44%
#   valid loss:		0.09603
#   valid accuracy:	0.98423+/-0.01381
#   valid auc-roc:	0.98107+/-0.02361
#   valid auc-pr:		0.82831+/-0.22286
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_13.pickle
# Epoch 15 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.09436 -- accuracy=98.45%
#   valid loss:		0.09329
#   valid accuracy:	0.98443+/-0.01353
#   valid auc-roc:	0.98156+/-0.02234
#   valid auc-pr:		0.83056+/-0.22154
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_14.pickle
# Epoch 16 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.09229 -- accuracy=98.46%
#   valid loss:		0.09187
#   valid accuracy:	0.98438+/-0.01385
#   valid auc-roc:	0.98176+/-0.02181
#   valid auc-pr:		0.83145+/-0.21965
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_15.pickle
# Epoch 17 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.09046 -- accuracy=98.46%
#   valid loss:		0.08919
#   valid accuracy:	0.98467+/-0.01347
#   valid auc-roc:	0.98202+/-0.02148
#   valid auc-pr:		0.83215+/-0.22136
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_16.pickle
# Epoch 18 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08874 -- accuracy=98.47%
#   valid loss:		0.08755
#   valid accuracy:	0.98477+/-0.01350
#   valid auc-roc:	0.98201+/-0.02209
#   valid auc-pr:		0.83335+/-0.22244
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_17.pickle
# Epoch 19 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08721 -- accuracy=98.48%
#   valid loss:		0.08619
#   valid accuracy:	0.98458+/-0.01374
#   valid auc-roc:	0.98214+/-0.02193
#   valid auc-pr:		0.83452+/-0.21993
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_18.pickle
# Epoch 20 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08571 -- accuracy=98.48%
#   valid loss:		0.08574
#   valid accuracy:	0.98462+/-0.01372
#   valid auc-roc:	0.98207+/-0.02170
#   valid auc-pr:		0.83434+/-0.21721
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_19.pickle
# Epoch 21 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08445 -- accuracy=98.49%
#   valid loss:		0.08371
#   valid accuracy:	0.98478+/-0.01341
#   valid auc-roc:	0.98286+/-0.02010
#   valid auc-pr:		0.83427+/-0.21830
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_20.pickle
# Epoch 22 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08324 -- accuracy=98.49%
#   valid loss:		0.08239
#   valid accuracy:	0.98492+/-0.01333
#   valid auc-roc:	0.98316+/-0.01984
#   valid auc-pr:		0.83858+/-0.21142
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_21.pickle
# Epoch 23 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08212 -- accuracy=98.49%
#   valid loss:		0.08135
#   valid accuracy:	0.98505+/-0.01327
#   valid auc-roc:	0.98317+/-0.01936
#   valid auc-pr:		0.83806+/-0.21336
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_22.pickle
# Epoch 24 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08108 -- accuracy=98.50%
#   valid loss:		0.08028
#   valid accuracy:	0.98499+/-0.01324
#   valid auc-roc:	0.98323+/-0.01877
#   valid auc-pr:		0.84140+/-0.20013
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_23.pickle
# Epoch 25 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08007 -- accuracy=98.50%
#   valid loss:		0.07945
#   valid accuracy:	0.98505+/-0.01326
#   valid auc-roc:	0.98314+/-0.01950
#   valid auc-pr:		0.84045+/-0.21092
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_24.pickle
# Epoch 26 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07922 -- accuracy=98.51%
#   valid loss:		0.07869
#   valid accuracy:	0.98487+/-0.01347
#   valid auc-roc:	0.98372+/-0.01788
#   valid auc-pr:		0.84427+/-0.19204
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_25.pickle
# Epoch 27 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07844 -- accuracy=98.51%
#   valid loss:		0.07744
#   valid accuracy:	0.98520+/-0.01325
#   valid auc-roc:	0.98435+/-0.01701
#   valid auc-pr:		0.84598+/-0.19659
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_26.pickle
# Epoch 28 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07776 -- accuracy=98.51%
#   valid loss:		0.07732
#   valid accuracy:	0.98510+/-0.01327
#   valid auc-roc:	0.98374+/-0.01829
#   valid auc-pr:		0.84632+/-0.19479
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_27.pickle
# Epoch 29 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07708 -- accuracy=98.51%
#   valid loss:		0.07634
#   valid accuracy:	0.98513+/-0.01329
#   valid auc-roc:	0.98466+/-0.01635
#   valid auc-pr:		0.84972+/-0.18487
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_28.pickle
# Epoch 30 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07643 -- accuracy=98.51%
#   valid loss:		0.07583
#   valid accuracy:	0.98518+/-0.01326
#   valid auc-roc:	0.98467+/-0.01611
#   valid auc-pr:		0.85029+/-0.18329
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_29.pickle
# Epoch 31 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07579 -- accuracy=98.51%
#   valid loss:		0.07520
#   valid accuracy:	0.98510+/-0.01342
#   valid auc-roc:	0.98497+/-0.01580
#   valid auc-pr:		0.85101+/-0.18091
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_30.pickle
# Epoch 32 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07514 -- accuracy=98.52%
#   valid loss:		0.07475
#   valid accuracy:	0.98518+/-0.01319
#   valid auc-roc:	0.98485+/-0.01596
#   valid auc-pr:		0.85151+/-0.17846
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_31.pickle
# Epoch 33 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07458 -- accuracy=98.52%
#   valid loss:		0.07406
#   valid accuracy:	0.98526+/-0.01326
#   valid auc-roc:	0.98472+/-0.01638
#   valid auc-pr:		0.85374+/-0.17713
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_32.pickle
# Epoch 34 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07395 -- accuracy=98.53%
#   valid loss:		0.07349
#   valid accuracy:	0.98525+/-0.01340
#   valid auc-roc:	0.98475+/-0.01599
#   valid auc-pr:		0.85376+/-0.17762
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_33.pickle
# Epoch 35 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07342 -- accuracy=98.53%
#   valid loss:		0.07313
#   valid accuracy:	0.98531+/-0.01313
#   valid auc-roc:	0.98483+/-0.01563
#   valid auc-pr:		0.85240+/-0.17924
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_34.pickle
# Epoch 36 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07285 -- accuracy=98.53%
#   valid loss:		0.07230
#   valid accuracy:	0.98528+/-0.01318
#   valid auc-roc:	0.98510+/-0.01554
#   valid auc-pr:		0.85502+/-0.17397
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_35.pickle
# Epoch 37 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07242 -- accuracy=98.53%
#   valid loss:		0.07191
#   valid accuracy:	0.98543+/-0.01325
#   valid auc-roc:	0.98494+/-0.01579
#   valid auc-pr:		0.85488+/-0.17651
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_36.pickle
# Epoch 38 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07202 -- accuracy=98.53%
#   valid loss:		0.07123
#   valid accuracy:	0.98546+/-0.01306
#   valid auc-roc:	0.98530+/-0.01506
#   valid auc-pr:		0.85808+/-0.16892
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_37.pickle
# Epoch 39 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07157 -- accuracy=98.53%
#   valid loss:		0.07126
#   valid accuracy:	0.98532+/-0.01323
#   valid auc-roc:	0.98481+/-0.01542
#   valid auc-pr:		0.85531+/-0.17462
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_38.pickle
# Epoch 40 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07117 -- accuracy=98.53%
#   valid loss:		0.07073
#   valid accuracy:	0.98532+/-0.01309
#   valid auc-roc:	0.98518+/-0.01552
#   valid auc-pr:		0.85581+/-0.17412
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_39.pickle
# Epoch 41 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07079 -- accuracy=98.54%
#   valid loss:		0.07032
#   valid accuracy:	0.98535+/-0.01326
#   valid auc-roc:	0.98515+/-0.01517
#   valid auc-pr:		0.85631+/-0.17168
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_40.pickle
# Epoch 42 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07036 -- accuracy=98.54%
#   valid loss:		0.06997
#   valid accuracy:	0.98538+/-0.01320
#   valid auc-roc:	0.98528+/-0.01512
#   valid auc-pr:		0.85672+/-0.17295
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_41.pickle
# Epoch 43 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06999 -- accuracy=98.54%
#   valid loss:		0.06932
#   valid accuracy:	0.98559+/-0.01317
#   valid auc-roc:	0.98535+/-0.01536
#   valid auc-pr:		0.85840+/-0.16894
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_42.pickle
# Epoch 44 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06971 -- accuracy=98.54%
#   valid loss:		0.06927
#   valid accuracy:	0.98550+/-0.01314
#   valid auc-roc:	0.98508+/-0.01552
#   valid auc-pr:		0.85668+/-0.17206
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_43.pickle
# Epoch 45 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06943 -- accuracy=98.54%
#   valid loss:		0.06909
#   valid accuracy:	0.98541+/-0.01303
#   valid auc-roc:	0.98523+/-0.01514
#   valid auc-pr:		0.85726+/-0.17117
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_44.pickle
# Epoch 46 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06921 -- accuracy=98.54%
#   valid loss:		0.06882
#   valid accuracy:	0.98541+/-0.01322
#   valid auc-roc:	0.98526+/-0.01545
#   valid auc-pr:		0.85502+/-0.17381
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_45.pickle
# Epoch 47 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06877 -- accuracy=98.54%
#   valid loss:		0.06816
#   valid accuracy:	0.98557+/-0.01310
#   valid auc-roc:	0.98523+/-0.01563
#   valid auc-pr:		0.85745+/-0.17238
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_46.pickle
# Epoch 48 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06851 -- accuracy=98.54%
#   valid loss:		0.06844
#   valid accuracy:	0.98525+/-0.01327
#   valid auc-roc:	0.98503+/-0.01558
#   valid auc-pr:		0.85718+/-0.17300
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_47.pickle
# Epoch 49 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06821 -- accuracy=98.55%
#   valid loss:		0.06777
#   valid accuracy:	0.98545+/-0.01315
#   valid auc-roc:	0.98492+/-0.01620
#   valid auc-pr:		0.85613+/-0.17645
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_48.pickle
# Epoch 50 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06794 -- accuracy=98.55%
#   valid loss:		0.06729
#   valid accuracy:	0.98552+/-0.01316
#   valid auc-roc:	0.98543+/-0.01538
#   valid auc-pr:		0.85976+/-0.16804
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_49.pickle
# Epoch 51 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06770 -- accuracy=98.55%
#   valid loss:		0.06723
#   valid accuracy:	0.98551+/-0.01311
#   valid auc-roc:	0.98536+/-0.01523
#   valid auc-pr:		0.85729+/-0.17271
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_50.pickle
# Epoch 52 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06731 -- accuracy=98.56%
#   valid loss:		0.06672
#   valid accuracy:	0.98560+/-0.01296
#   valid auc-roc:	0.98557+/-0.01497
#   valid auc-pr:		0.85817+/-0.17207
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_51.pickle
# Epoch 53 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06720 -- accuracy=98.54%
#   valid loss:		0.06686
#   valid accuracy:	0.98548+/-0.01314
#   valid auc-roc:	0.98497+/-0.01580
#   valid auc-pr:		0.85799+/-0.17301
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_52.pickle
# Epoch 54 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06695 -- accuracy=98.55%
#   valid loss:		0.06655
#   valid accuracy:	0.98563+/-0.01291
#   valid auc-roc:	0.98528+/-0.01532
#   valid auc-pr:		0.85789+/-0.17119
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_53.pickle
# Epoch 55 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06668 -- accuracy=98.55%
#   valid loss:		0.06658
#   valid accuracy:	0.98545+/-0.01312
#   valid auc-roc:	0.98512+/-0.01542
#   valid auc-pr:		0.85647+/-0.17347
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_54.pickle
# Epoch 56 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06659 -- accuracy=98.55%
#   valid loss:		0.06594
#   valid accuracy:	0.98560+/-0.01312
#   valid auc-roc:	0.98561+/-0.01481
#   valid auc-pr:		0.86064+/-0.16731
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_55.pickle
# Epoch 57 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06635 -- accuracy=98.55%
#   valid loss:		0.06588
#   valid accuracy:	0.98564+/-0.01311
#   valid auc-roc:	0.98537+/-0.01534
#   valid auc-pr:		0.85883+/-0.17085
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_56.pickle
# Epoch 58 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06617 -- accuracy=98.55%
#   valid loss:		0.06572
#   valid accuracy:	0.98562+/-0.01312
#   valid auc-roc:	0.98577+/-0.01453
#   valid auc-pr:		0.85900+/-0.16968
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_57.pickle
# Epoch 59 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06600 -- accuracy=98.55%
#   valid loss:		0.06565
#   valid accuracy:	0.98560+/-0.01300
#   valid auc-roc:	0.98549+/-0.01520
#   valid auc-pr:		0.85883+/-0.16880
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_58.pickle
# Epoch 60 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06592 -- accuracy=98.55%
#   valid loss:		0.06554
#   valid accuracy:	0.98548+/-0.01320
#   valid auc-roc:	0.98563+/-0.01477
#   valid auc-pr:		0.85860+/-0.17097
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_59.pickle
# Epoch 61 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06579 -- accuracy=98.55%
#   valid loss:		0.06557
#   valid accuracy:	0.98554+/-0.01303
#   valid auc-roc:	0.98521+/-0.01536
#   valid auc-pr:		0.85908+/-0.16841
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_60.pickle
# Epoch 62 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06552 -- accuracy=98.55%
#   valid loss:		0.06485
#   valid accuracy:	0.98563+/-0.01311
#   valid auc-roc:	0.98590+/-0.01463
#   valid auc-pr:		0.85963+/-0.17148
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_61.pickle
# Epoch 63 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06537 -- accuracy=98.55%
#   valid loss:		0.06470
#   valid accuracy:	0.98567+/-0.01297
#   valid auc-roc:	0.98558+/-0.01490
#   valid auc-pr:		0.85955+/-0.16926
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_62.pickle
# Epoch 64 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06512 -- accuracy=98.56%
#   valid loss:		0.06459
#   valid accuracy:	0.98571+/-0.01307
#   valid auc-roc:	0.98581+/-0.01488
#   valid auc-pr:		0.86074+/-0.16688
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_63.pickle
# Epoch 65 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06498 -- accuracy=98.56%
#   valid loss:		0.06455
#   valid accuracy:	0.98562+/-0.01298
#   valid auc-roc:	0.98545+/-0.01516
#   valid auc-pr:		0.86139+/-0.16713
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_64.pickle
# Epoch 66 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06484 -- accuracy=98.56%
#   valid loss:		0.06451
#   valid accuracy:	0.98563+/-0.01305
#   valid auc-roc:	0.98528+/-0.01535
#   valid auc-pr:		0.85955+/-0.16800
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_65.pickle
# Epoch 67 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06473 -- accuracy=98.55%
#   valid loss:		0.06404
#   valid accuracy:	0.98569+/-0.01303
#   valid auc-roc:	0.98580+/-0.01466
#   valid auc-pr:		0.86062+/-0.16853
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_66.pickle
# Epoch 68 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06457 -- accuracy=98.55%
#   valid loss:		0.06424
#   valid accuracy:	0.98567+/-0.01298
#   valid auc-roc:	0.98546+/-0.01491
#   valid auc-pr:		0.86145+/-0.16624
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_67.pickle
# Epoch 69 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06441 -- accuracy=98.56%
#   valid loss:		0.06385
#   valid accuracy:	0.98568+/-0.01303
#   valid auc-roc:	0.98558+/-0.01520
#   valid auc-pr:		0.85949+/-0.17107
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_68.pickle
# Epoch 70 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06428 -- accuracy=98.56%
#   valid loss:		0.06382
#   valid accuracy:	0.98565+/-0.01302
#   valid auc-roc:	0.98580+/-0.01459
#   valid auc-pr:		0.86114+/-0.16671
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_69.pickle
# Epoch 71 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06414 -- accuracy=98.56%
#   valid loss:		0.06395
#   valid accuracy:	0.98563+/-0.01302
#   valid auc-roc:	0.98568+/-0.01477
#   valid auc-pr:		0.85841+/-0.17058
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_70.pickle
# Epoch 72 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06407 -- accuracy=98.55%
#   valid loss:		0.06360
#   valid accuracy:	0.98559+/-0.01306
#   valid auc-roc:	0.98583+/-0.01489
#   valid auc-pr:		0.86164+/-0.16622
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_71.pickle
# Epoch 73 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06399 -- accuracy=98.56%
#   valid loss:		0.06357
#   valid accuracy:	0.98555+/-0.01316
#   valid auc-roc:	0.98572+/-0.01480
#   valid auc-pr:		0.86154+/-0.16604
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_72.pickle
# Epoch 74 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06380 -- accuracy=98.56%
#   valid loss:		0.06322
#   valid accuracy:	0.98573+/-0.01292
#   valid auc-roc:	0.98550+/-0.01530
#   valid auc-pr:		0.86231+/-0.16472
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_73.pickle
# Epoch 75 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06369 -- accuracy=98.56%
#   valid loss:		0.06334
#   valid accuracy:	0.98566+/-0.01304
#   valid auc-roc:	0.98535+/-0.01510
#   valid auc-pr:		0.86033+/-0.16817
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_74.pickle
# Epoch 76 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06355 -- accuracy=98.56%
#   valid loss:		0.06295
#   valid accuracy:	0.98571+/-0.01306
#   valid auc-roc:	0.98565+/-0.01521
#   valid auc-pr:		0.86262+/-0.16749
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_75.pickle
# Epoch 77 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06353 -- accuracy=98.55%
#   valid loss:		0.06291
#   valid accuracy:	0.98563+/-0.01301
#   valid auc-roc:	0.98557+/-0.01550
#   valid auc-pr:		0.86204+/-0.16650
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_76.pickle
# Epoch 78 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06330 -- accuracy=98.56%
#   valid loss:		0.06303
#   valid accuracy:	0.98564+/-0.01303
#   valid auc-roc:	0.98562+/-0.01508
#   valid auc-pr:		0.86043+/-0.17003
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_77.pickle
# Epoch 79 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06325 -- accuracy=98.56%
#   valid loss:		0.06307
#   valid accuracy:	0.98558+/-0.01304
#   valid auc-roc:	0.98562+/-0.01501
#   valid auc-pr:		0.86105+/-0.16722
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_78.pickle
# Epoch 80 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06316 -- accuracy=98.56%
#   valid loss:		0.06281
#   valid accuracy:	0.98564+/-0.01311
#   valid auc-roc:	0.98559+/-0.01529
#   valid auc-pr:		0.86092+/-0.16994
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_79.pickle
# Epoch 81 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06304 -- accuracy=98.56%
#   valid loss:		0.06274
#   valid accuracy:	0.98569+/-0.01292
#   valid auc-roc:	0.98591+/-0.01467
#   valid auc-pr:		0.86080+/-0.16686
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_80.pickle
# Epoch 82 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06295 -- accuracy=98.56%
#   valid loss:		0.06235
#   valid accuracy:	0.98576+/-0.01285
#   valid auc-roc:	0.98567+/-0.01506
#   valid auc-pr:		0.86134+/-0.16722
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_81.pickle
# Epoch 83 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06292 -- accuracy=98.56%
#   valid loss:		0.06266
#   valid accuracy:	0.98564+/-0.01306
#   valid auc-roc:	0.98573+/-0.01453
#   valid auc-pr:		0.86240+/-0.16474
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_82.pickle
# Epoch 84 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06274 -- accuracy=98.57%
#   valid loss:		0.06273
#   valid accuracy:	0.98561+/-0.01302
#   valid auc-roc:	0.98571+/-0.01455
#   valid auc-pr:		0.86197+/-0.16416
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_83.pickle
# Epoch 85 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06269 -- accuracy=98.56%
#   valid loss:		0.06251
#   valid accuracy:	0.98563+/-0.01315
#   valid auc-roc:	0.98571+/-0.01456
#   valid auc-pr:		0.86091+/-0.16744
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_84.pickle
# Epoch 86 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06264 -- accuracy=98.56%
#   valid loss:		0.06212
#   valid accuracy:	0.98573+/-0.01298
#   valid auc-roc:	0.98609+/-0.01445
#   valid auc-pr:		0.86151+/-0.16970
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_85.pickle
# Epoch 87 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06263 -- accuracy=98.56%
#   valid loss:		0.06237
#   valid accuracy:	0.98561+/-0.01315
#   valid auc-roc:	0.98579+/-0.01477
#   valid auc-pr:		0.86148+/-0.16668
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_86.pickle
# Epoch 88 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06248 -- accuracy=98.56%
#   valid loss:		0.06209
#   valid accuracy:	0.98564+/-0.01307
#   valid auc-roc:	0.98598+/-0.01455
#   valid auc-pr:		0.86013+/-0.16899
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_87.pickle
# Epoch 89 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06243 -- accuracy=98.56%
#   valid loss:		0.06241
#   valid accuracy:	0.98564+/-0.01307
#   valid auc-roc:	0.98569+/-0.01506
#   valid auc-pr:		0.86054+/-0.16906
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_88.pickle
# Epoch 90 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06235 -- accuracy=98.56%
#   valid loss:		0.06225
#   valid accuracy:	0.98558+/-0.01310
#   valid auc-roc:	0.98573+/-0.01476
#   valid auc-pr:		0.86091+/-0.16922
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_89.pickle
# Epoch 91 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06220 -- accuracy=98.56%
#   valid loss:		0.06221
#   valid accuracy:	0.98558+/-0.01302
#   valid auc-roc:	0.98583+/-0.01454
#   valid auc-pr:		0.86087+/-0.16706
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_90.pickle
# Epoch 92 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06218 -- accuracy=98.57%
#   valid loss:		0.06176
#   valid accuracy:	0.98568+/-0.01297
#   valid auc-roc:	0.98607+/-0.01424
#   valid auc-pr:		0.86236+/-0.16638
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_91.pickle
# Epoch 93 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06208 -- accuracy=98.56%
#   valid loss:		0.06180
#   valid accuracy:	0.98571+/-0.01305
#   valid auc-roc:	0.98585+/-0.01498
#   valid auc-pr:		0.86198+/-0.16780
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_92.pickle
# Epoch 94 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06201 -- accuracy=98.56%
#   valid loss:		0.06168
#   valid accuracy:	0.98571+/-0.01303
#   valid auc-roc:	0.98581+/-0.01486
#   valid auc-pr:		0.86114+/-0.16903
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_93.pickle
# Epoch 95 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06195 -- accuracy=98.57%
#   valid loss:		0.06166
#   valid accuracy:	0.98562+/-0.01310
#   valid auc-roc:	0.98601+/-0.01442
#   valid auc-pr:		0.86200+/-0.16515
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_94.pickle
# Epoch 96 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06186 -- accuracy=98.56%
#   valid loss:		0.06187
#   valid accuracy:	0.98554+/-0.01320
#   valid auc-roc:	0.98582+/-0.01441
#   valid auc-pr:		0.86076+/-0.16757
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_95.pickle
# Epoch 97 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06180 -- accuracy=98.57%
#   valid loss:		0.06151
#   valid accuracy:	0.98574+/-0.01305
#   valid auc-roc:	0.98601+/-0.01456
#   valid auc-pr:		0.86119+/-0.16921
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_96.pickle
# Epoch 98 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06178 -- accuracy=98.57%
#   valid loss:		0.06173
#   valid accuracy:	0.98557+/-0.01313
#   valid auc-roc:	0.98618+/-0.01433
#   valid auc-pr:		0.86184+/-0.16927
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_97.pickle
# Epoch 99 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06172 -- accuracy=98.56%
#   valid loss:		0.06136
#   valid accuracy:	0.98570+/-0.01302
#   valid auc-roc:	0.98612+/-0.01443
#   valid auc-pr:		0.86224+/-0.16759
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_98.pickle
# Epoch 100 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06166 -- accuracy=98.56%
#   valid loss:		0.06131
#   valid accuracy:	0.98568+/-0.01300
#   valid auc-roc:	0.98571+/-0.01508
#   valid auc-pr:		0.86265+/-0.16484
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_99.pickle
# Epoch 101 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06160 -- accuracy=98.56%
#   valid loss:		0.06150
#   valid accuracy:	0.98558+/-0.01320
#   valid auc-roc:	0.98593+/-0.01450
#   valid auc-pr:		0.86233+/-0.16578
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_100.pickle
# Epoch 102 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06152 -- accuracy=98.57%
#   valid loss:		0.06100
#   valid accuracy:	0.98572+/-0.01304
#   valid auc-roc:	0.98616+/-0.01427
#   valid auc-pr:		0.86300+/-0.16592
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_101.pickle
# Epoch 103 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06145 -- accuracy=98.57%
#   valid loss:		0.06107
#   valid accuracy:	0.98572+/-0.01299
#   valid auc-roc:	0.98594+/-0.01436
#   valid auc-pr:		0.86167+/-0.16645
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_102.pickle
# Epoch 104 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06141 -- accuracy=98.57%
#   valid loss:		0.06116
#   valid accuracy:	0.98569+/-0.01301
#   valid auc-roc:	0.98590+/-0.01462
#   valid auc-pr:		0.86213+/-0.16707
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_103.pickle
# Epoch 105 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06132 -- accuracy=98.57%
#   valid loss:		0.06096
#   valid accuracy:	0.98571+/-0.01304
#   valid auc-roc:	0.98574+/-0.01471
#   valid auc-pr:		0.86042+/-0.17172
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_104.pickle
# Epoch 106 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06128 -- accuracy=98.56%
#   valid loss:		0.06111
#   valid accuracy:	0.98571+/-0.01298
#   valid auc-roc:	0.98606+/-0.01474
#   valid auc-pr:		0.86143+/-0.16847
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_105.pickle
# Epoch 107 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06130 -- accuracy=98.56%
#   valid loss:		0.06109
#   valid accuracy:	0.98575+/-0.01292
#   valid auc-roc:	0.98597+/-0.01469
#   valid auc-pr:		0.86166+/-0.16706
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_106.pickle
# Epoch 108 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06116 -- accuracy=98.56%
#   valid loss:		0.06122
#   valid accuracy:	0.98564+/-0.01304
#   valid auc-roc:	0.98584+/-0.01469
#   valid auc-pr:		0.86022+/-0.17091
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_107.pickle
# Epoch 109 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06121 -- accuracy=98.57%
#   valid loss:		0.06127
#   valid accuracy:	0.98558+/-0.01302
#   valid auc-roc:	0.98572+/-0.01477
#   valid auc-pr:		0.86160+/-0.16680
# saving model parameters to: /home/peter/Data/SequenceMotif/Unlocalized_N=300000_S=200_M=50_G=20_data.pickle_epoch_108.pickle
# Patience ran out... Early stopping.

# %%
#epoch = 111
#savepath = filepath + "_epoch_" + str(epoch) + ".pickle"
#nnmodel.set_parameters_from_file(savepath)

# %%
network = nnmodel.network
network
# Out:
# {'conv1': <lasagne.layers.dnn.Conv2DDNNLayer at 0x7f995a675ad0>,
#  'conv1_active': <lasagne.layers.special.ParametricRectifierLayer at 0x7f9950c7c250>,
#  'conv1_batch': <lasagne.layers.normalization.BatchNormLayer at 0x7f99c05a3890>,
#  'conv1_bias': <lasagne.layers.special.BiasLayer at 0x7f99c05a3710>,
#  'conv1_pool': <lasagne.layers.pool.MaxPool2DLayer at 0x7f995a66b1d0>,
#  'conv2': <lasagne.layers.dnn.Conv2DDNNLayer at 0x7f9950c7c290>,
#  'conv2_active': <lasagne.layers.special.ParametricRectifierLayer at 0x7f9950c7cc50>,
#  'conv2_batch': <lasagne.layers.normalization.BatchNormLayer at 0x7f9950c7c590>,
#  'conv2_bias': <lasagne.layers.special.BiasLayer at 0x7f9950c7c450>,
#  'conv2_pool': <lasagne.layers.pool.MaxPool2DLayer at 0x7f9950c7c710>,
#  'conv3': <lasagne.layers.dnn.Conv2DDNNLayer at 0x7f9950c7cc90>,
#  'conv3_active': <lasagne.layers.special.ParametricRectifierLayer at 0x7f9950c82690>,
#  'conv3_batch': <lasagne.layers.normalization.BatchNormLayer at 0x7f9950c7cf90>,
#  'conv3_bias': <lasagne.layers.special.BiasLayer at 0x7f9950c7ce50>,
#  'conv3_pool': <lasagne.layers.pool.MaxPool2DLayer at 0x7f9950c82150>,
#  'conv4': <lasagne.layers.dnn.Conv2DDNNLayer at 0x7f9950c826d0>,
#  'conv4_active': <lasagne.layers.special.ParametricRectifierLayer at 0x7f9950c91190>,
#  'conv4_batch': <lasagne.layers.normalization.BatchNormLayer at 0x7f9950c82a90>,
#  'conv4_bias': <lasagne.layers.special.BiasLayer at 0x7f9950c82890>,
#  'conv4_pool': <lasagne.layers.pool.MaxPool2DLayer at 0x7f9950c82c10>,
#  'dense1': <lasagne.layers.dense.DenseLayer at 0x7f9950c911d0>,
#  'dense1_active': <lasagne.layers.special.ParametricRectifierLayer at 0x7f9950c91f50>,
#  'dense1_batch': <lasagne.layers.normalization.BatchNormLayer at 0x7f9950c91850>,
#  'dense1_bias': <lasagne.layers.special.BiasLayer at 0x7f9950c91390>,
#  'dense2': <lasagne.layers.dense.DenseLayer at 0x7f9950c919d0>,
#  'dense2_active': <lasagne.layers.special.NonlinearityLayer at 0x7f9950c9c2d0>,
#  'dense2_bias': <lasagne.layers.special.BiasLayer at 0x7f9950c91f90>,
#  'input': <lasagne.layers.input.InputLayer at 0x7f995a675a50>,
#  'output': <lasagne.layers.special.NonlinearityLayer at 0x7f9950c9c2d0>}

# %%
def get_output(X,layer):
    num_data = len(X)
    feature_maps = theano.function([nnmodel.input_var], layers.get_output(layer,deterministic=True), allow_input_downcast=True)
    map_shape = get_output_shape(layer)

    # get feature maps in batches for speed (large batches may be too much memory for GPU)
    batch_size=500
    num_batches = num_data // batch_size
    shape = list(map_shape)
    shape[0] = num_data
    output = np.empty(tuple(shape))
    for i in range(num_batches):
        index = range(i*batch_size, (i+1)*batch_size)    
        output[index] = feature_maps(X[index])

    # get the rest of the feature maps
    excess = num_data-num_batches*batch_size
    if excess:
        index = range(num_data-excess, num_data)  
        output[index] = feature_maps(X[index])
    return output


X = train[0]
layer = network['output']
output = get_output(X,layer)
output2 = get_output(test[0],layer)

# %%
output2
# Out:
# array([[  8.17371983e-05,   2.82243290e-03,   2.62854621e-04, ...,
#           6.23436761e-04,   1.15592498e-03,   1.96455326e-03],
#        [  5.42667054e-04,   1.00614736e-02,   1.66675530e-03, ...,
#           3.28011625e-03,   7.59914226e-04,   5.67468756e-04],
#        [  4.06651263e-04,   2.87878327e-03,   8.02329800e-04, ...,
#           2.24312185e-03,   3.76688520e-04,   2.46798358e-04],
#        ...,
#        [  2.11924154e-04,   1.52468405e-04,   1.01302995e-03, ...,
#           1.58806768e-04,   4.23517267e-05,   1.53495930e-04],
#        [  4.81370116e-05,   5.92674653e-04,   5.73735888e-05, ...,
#           4.18596290e-04,   7.55473084e-05,   5.71259479e-05],
#        [  6.97211013e-04,   4.28354414e-03,   3.09815514e-04, ...,
#           1.71212375e-03,   2.60388188e-04,   2.08732366e-04]])

# %%
shape2 = list(output.shape)
shape2[0] = None
input_var2 = T.dmatrix('input')
input_var2 = T.cast(input_var2, 'float32')


deconv = {}
deconv['input'] = InputLayer(tuple(shape2), input_var=input_var2)
num_units = list(get_output_shape(network['dense1']))[1]
deconv['dense2'] = layers.DenseLayer(deconv['input'], num_units=num_units, W=network['dense2'].W.dimshuffle([1,0]), 
                                     b=init.Constant(0.05), nonlinearity=None)
#deconv['dense2'].params[deconv['dense2'].W].remove('trainable')
#deconv['dense2_norm'] = layers.BatchNormLayer(deconv['dense2'])
deconv['dense2_active'] = layers.ParametricRectifierLayer(deconv['dense2'], alpha=init.Constant(0.25))
#deconv['dense2_active'] = layers.NonlinearityLayer(deconv['dense2'], nonlinearity=nonlinearities.rectify)

num_units = np.prod(list(get_output_shape(network['conv4_pool']))[1:])
deconv['dense1'] = layers.DenseLayer(deconv['dense2_active'], num_units=num_units, W=network['dense1'].W.dimshuffle([1,0]), 
                                     b=init.Constant(0.05), nonlinearity=None)
#deconv['dense1'].params[deconv['dense1'].W].remove('trainable')
#deconv['dense1_norm'] = layers.BatchNormLayer(deconv['dense1'])
deconv['dense1_active'] = layers.ParametricRectifierLayer(deconv['dense1'], alpha=init.Constant(0.25))
#deconv['dense1_active'] = layers.NonlinearityLayer(deconv['dense1'], nonlinearity=nonlinearities.rectify)

shape = list(get_output_shape(network['conv4_pool']))
shape[0] = -1
deconv['reshape'] = layers.ReshapeLayer(deconv['dense1_active'], shape=tuple(shape))

deconv['pool4'] = layers.Upscale2DLayer(deconv['reshape'], (2,1))
deconv['conv4']  = Conv2DLayer(deconv['pool4'], num_filters=network['conv4'].input_shape[1],
                                          filter_size=network['conv4'].filter_size,
                                          W=network['conv4'].W.dimshuffle([1,0,2,3]), #W2_inv, #
                                          b=init.Constant(0.05), 
                                          pad='same',
                                          nonlinearity=None, flip_filters=True)
#deconv['conv2'].params[deconv['conv2'].W].remove('trainable')
#deconv['conv2_norm'] = layers.BatchNormLayer(deconv['conv2'])
deconv['conv4_active'] = layers.ParametricRectifierLayer(deconv['conv4'], alpha=init.Constant(0.25))
#deconv['conv4_active'] = layers.NonlinearityLayer(deconv['conv4'], nonlinearity=nonlinearities.rectify)

deconv['pool3'] = layers.Upscale2DLayer(deconv['conv4_active'], (2,1))
deconv['conv3']  = Conv2DLayer(deconv['pool3'], num_filters=network['conv3'].input_shape[1],
                                          filter_size=network['conv3'].filter_size,
                                          W=network['conv3'].W.dimshuffle([1,0,2,3]), #W2_inv, #
                                          b=init.Constant(0.5), 
                                          pad='same',
                                          nonlinearity=None, flip_filters=True)
#deconv['conv2'].params[deconv['conv2'].W].remove('trainable')
#deconv['conv2_norm'] = layers.BatchNormLayer(deconv['conv2'])
deconv['conv3_active'] = layers.ParametricRectifierLayer(deconv['conv3'], alpha=init.Constant(0.25))
#deconv['conv3_active'] = layers.NonlinearityLayer(deconv['conv3'], nonlinearity=nonlinearities.rectify)

deconv['pool2'] = layers.Upscale2DLayer(deconv['conv3_active'], (5,1))
deconv['conv2']  = Conv2DLayer(deconv['pool2'], num_filters=network['conv2'].input_shape[1],
                                          filter_size=network['conv2'].filter_size,
                                          W=network['conv2'].W.dimshuffle([1,0,2,3]), #W2_inv, #
                                          b=init.Constant(0.05), 
                                          pad='same',
                                          nonlinearity=None, flip_filters=True)
#deconv['conv2'].params[deconv['conv2'].W].remove('trainable')
#deconv['conv2_norm'] = layers.BatchNormLayer(deconv['conv2'])
deconv['conv2_active'] = layers.ParametricRectifierLayer(deconv['conv2'], alpha=init.Constant(0.25))
#deconv['conv2_active'] = layers.NonlinearityLayer(deconv['conv2'], nonlinearity=nonlinearities.rectify)


deconv['pool1'] = layers.Upscale2DLayer(deconv['conv2_active'], (2,1))
deconv['conv1']  = Conv2DLayer(deconv['pool1'], num_filters=network['conv1'].input_shape[1],
                                          filter_size=network['conv1'].filter_size,
                                          W=network['conv1'].W.dimshuffle([1,0,2,3]), #W2_inv, #
                                          b=init.Constant(0.05), 
                                          pad='same',
                                          nonlinearity=None, flip_filters=True)
#deconv['conv1'].params[deconv['conv1'].W].remove('trainable')
#deconv['conv1_norm'] = layers.BatchNormLayer(deconv['conv1'])
deconv['conv1_active'] = layers.NonlinearityLayer(deconv['conv1'], nonlinearity=nonlinearities.sigmoid)

deconv['output'] = deconv['conv1_active']

# %%
from lasagne import updates, regularization

target_var = T.tensor4('targets')
prediction = layers.get_output(deconv['output'], deterministic=False)

loss = objectives.squared_error(prediction, target_var)
loss = objectives.aggregate(loss, mode='mean')

params = layers.get_all_params(deconv['output'], trainable=True)    
#l1_penalty = regularization.apply_penalty(params, regularization.l1)*1e-4
#l2_penalty = regularization.apply_penalty(params, regularization.l2)*1e-6
#loss = loss + l1_penalty + l2_penalt

grad = T.grad(loss, params)

#update_op = updates.adagrad(grad, params, learning_rate=0.001)
update_op = updates.adam(grad, params, learning_rate=0.0005)
#update_op = updates.nesterov_momentum(grad, params, learning_rate=0.001, momentum=0.9)

train_fun = theano.function([input_var2, target_var], [loss, prediction], updates=update_op)

# %%
def batch_generator(X, y, batch_size=128):
    for start_idx in range(0, len(X)-batch_size+1, batch_size):
        excerpt = slice(start_idx, start_idx+batch_size)
        yield X[excerpt].astype(np.float32), y[excerpt].astype(np.float32)

batch_size = 128        
for epoch in range(200):
    sys.stdout.write("\rEpoch %d \n"%(epoch+1))

    num_batches = output.shape[0] // batch_size
    batches = batch_generator(output, train[0], batch_size)
    value = 0
    for i in range(num_batches):
        X,y = next(batches)
        loss, prediction = train_fun(X, y)
        value += np.mean(loss)
    sys.stdout.write("\r  loss = %f \n"%(value/num_batches))
# Out:
# Epoch 1
#   loss = 0.186355
# Epoch 2
#   loss = 0.186301
# Epoch 3
#   loss = 0.186288
# Epoch 4
#   loss = 0.186282
# Epoch 5
#   loss = 0.186284
# Epoch 6
#   loss = 0.186283
# Epoch 7
#   loss = 0.186281
# Epoch 8
#   loss = 0.186281
# Epoch 9
#   loss = 0.186277
# Epoch 10
#   loss = 0.186277
# Epoch 11
#   loss = 0.186276
# Epoch 12
#   loss = 0.186275
# Epoch 13
#   loss = 0.186272
# Epoch 14
#   loss = 0.186272
# Epoch 15
#   loss = 0.186270
# Epoch 16
#   loss = 0.186267
# Epoch 17
#   loss = 0.186266
# Epoch 18
#   loss = 0.186265
# Epoch 19
#   loss = 0.186263
# Epoch 20
#   loss = 0.186260
# Epoch 21
#   loss = 0.186259
# Epoch 22
#   loss = 0.186257
# Epoch 23
#   loss = 0.186258
# Epoch 24
#   loss = 0.186254
# Epoch 25
#   loss = 0.186252
# Epoch 26
#   loss = 0.186250
# Epoch 27
#   loss = 0.186247
# Epoch 28
#   loss = 0.186247
# Epoch 29
#   loss = 0.186241
# Epoch 30
#   loss = 0.186241
# Epoch 31
#   loss = 0.186239
# Epoch 32
#   loss = 0.186239
# Epoch 33
#   loss = 0.186237
# Epoch 34
#   loss = 0.186234
# Epoch 35
#   loss = 0.186231
# Epoch 36
#   loss = 0.186228
# Epoch 37
#   loss = 0.186228
# Epoch 38
#   loss = 0.186224
# Epoch 39
#   loss = 0.186222
# Epoch 40
#   loss = 0.186219
# Epoch 41
#   loss = 0.186217
# Epoch 42
#   loss = 0.186216
# Epoch 43
#   loss = 0.186213
# Epoch 44
#   loss = 0.186210
# Epoch 45
#   loss = 0.186209
# Epoch 46
#   loss = 0.186209
# Epoch 47
#   loss = 0.186204
# Epoch 48
#   loss = 0.186202
# Epoch 49
#   loss = 0.186201
# Epoch 50
#   loss = 0.186199
# Epoch 51
#   loss = 0.186196
# Epoch 52
#   loss = 0.186194
# Epoch 53
#   loss = 0.186193
# Epoch 54
#   loss = 0.186192
# Epoch 55
#   loss = 0.186188
# Epoch 56
#   loss = 0.186186
# Epoch 57
#   loss = 0.186184
# Epoch 58
#   loss = 0.186182
# Epoch 59
#   loss = 0.186179
# Epoch 60
#   loss = 0.186178
# Epoch 61
#   loss = 0.186175
# Epoch 62
#   loss = 0.186172
# Epoch 63
#   loss = 0.186170
# Epoch 64
#   loss = 0.186168
# Epoch 65
#   loss = 0.186166
# Epoch 66
#   loss = 0.186165
# Epoch 67
#   loss = 0.186164
# Epoch 68
#   loss = 0.186161
# Epoch 69
#   loss = 0.186156
# Epoch 70
#   loss = 0.186156
# Epoch 71
#   loss = 0.186155
# Epoch 72
#   loss = 0.186153
# Epoch 73
#   loss = 0.186150
# Epoch 74
#   loss = 0.186148
# Epoch 75
#   loss = 0.186146
# Epoch 76
#   loss = 0.186144
# Epoch 77
#   loss = 0.186143
# Epoch 78
#   loss = 0.186142
# Epoch 79
#   loss = 0.186141
# Epoch 80
#   loss = 0.186140
# Epoch 81
#   loss = 0.186136
# Epoch 82
#   loss = 0.186135
# Epoch 83
#   loss = 0.186134
# Epoch 84
#   loss = 0.186133
# Epoch 85
#   loss = 0.186131
# Epoch 86
#   loss = 0.186128
# Epoch 87
#   loss = 0.186125
# Epoch 88
#   loss = 0.186125
# Epoch 89
#   loss = 0.186123
# Epoch 90
#   loss = 0.186119
# Epoch 91
#   loss = 0.186121
# Epoch 92
#   loss = 0.186114
# Epoch 93
#   loss = 0.186116
# Epoch 94
#   loss = 0.186115
# Epoch 95
#   loss = 0.186115
# Epoch 96
#   loss = 0.186110
# Epoch 97
#   loss = 0.186108
# Epoch 98
#   loss = 0.186106
# Epoch 99
#   loss = 0.186103
# Epoch 100
#   loss = 0.186100
# Epoch 101
#   loss = 0.186098
# Epoch 102
#   loss = 0.186096
# Epoch 103
#   loss = 0.186095
# Epoch 104
#   loss = 0.186093
# Epoch 105
#   loss = 0.186094
# Epoch 106
#   loss = 0.186093
# Epoch 107
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-651440ff5e2f> in <module>()
#      13     for i in range(num_batches):
#      14         X,y = next(batches)
# ---> 15         loss, prediction = train_fun(X, y)
#      16         value += np.mean(loss)
#      17     sys.stdout.write("\r  loss = %f \n"%(value/num_batches))
#
# /home/peter/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /home/peter/anaconda2/lib/python2.7/site-packages/theano/gof/op.pyc in rval(p, i, o, n)
#     909         if params is graph.NoParams:
#     910             # default arguments are stored in the closure of `rval`
# --> 911             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     912                 r = p(n, [x[0] for x in i], o)
#     913                 for o in node.outputs:
#
# KeyboardInterrupt:

# %%
def seq_logo(pwm, height=100, nt_width=20, norm=0, rna=1, filepath='.'):
    """generate a sequence logo from a pwm"""
    
    def load_alphabet(filepath, rna):
        """load images of nucleotide alphabet """
        df = pd.read_table(os.path.join(filepath, 'A.txt'), header=None);
        A_img = df.as_matrix()
        A_img = np.reshape(A_img, [72, 65, 3], order="F").astype(np.uint8)

        df = pd.read_table(os.path.join(filepath, 'C.txt'), header=None);
        C_img = df.as_matrix()
        C_img = np.reshape(C_img, [76, 64, 3], order="F").astype(np.uint8)

        df = pd.read_table(os.path.join(filepath, 'G.txt'), header=None);
        G_img = df.as_matrix()
        G_img = np.reshape(G_img, [76, 67, 3], order="F").astype(np.uint8)

        if rna == 1:
            df = pd.read_table(os.path.join(filepath, 'U.txt'), header=None);
            T_img = df.as_matrix()
            T_img = np.reshape(T_img, [74, 57, 3], order="F").astype(np.uint8)
        else:
            df = pd.read_table(os.path.join(filepath, 'T.txt'), header=None);
            T_img = df.as_matrix()
            T_img = np.reshape(T_img, [72, 59, 3], order="F").astype(np.uint8)

        return A_img, C_img, G_img, T_img


    def get_nt_height(pwm, height, norm):
        """get the heights of each nucleotide"""

        def entropy(p):
            """calculate entropy of each nucleotide"""
            s = 0
            for i in range(4):
                if p[i] > 0:
                    s -= p[i]*np.log2(p[i])
            return s

        num_nt, num_seq = pwm.shape
        heights = np.zeros((num_nt,num_seq));
        for i in range(num_seq):
            if norm == 1:
                total_height = height
            else:
                total_height = (np.log2(4) - entropy(pwm[:, i]))*height;
            heights[:,i] = np.floor(pwm[:,i]*total_height);
        return heights.astype(int)

    
    # get the alphabet images of each nucleotide
    A_img, C_img, G_img, T_img = load_alphabet(filepath='.', rna=1)
    
    
    # get the heights of each nucleotide
    heights = get_nt_height(pwm, height, norm)
    
    # resize nucleotide images for each base of sequence and stack
    num_nt, num_seq = pwm.shape
    width = np.ceil(nt_width*num_seq).astype(int)
    
    total_height = np.sum(heights,axis=0)
    max_height = np.max(total_height)
    logo = np.ones((height*2, width, 3)).astype(int)*255;
    for i in range(num_seq):
        remaining_height = total_height[i];
        offset = max_height-remaining_height
        nt_height = np.sort(heights[:,i]);
        index = np.argsort(heights[:,i])

        for j in range(num_nt):
            if nt_height[j] > 0:
                # resized dimensions of image
                resize = (nt_height[j], nt_width)
                if index[j] == 0:
                    nt_img = imresize(A_img, resize)
                elif index[j] == 1:
                    nt_img = imresize(C_img, resize)
                elif index[j] == 2:
                    nt_img = imresize(G_img, resize)
                elif index[j] == 3:
                    nt_img = imresize(T_img, resize)

                # determine location of image
                height_range = range(remaining_height-nt_height[j], remaining_height)
                width_range = range(i*nt_width, i*nt_width+nt_width)

                # 'annoying' way to broadcast resized nucleotide image
                if height_range:
                    for k in range(3):
                        for m in range(len(width_range)):
                            logo[height_range+offset, width_range[m],k] = nt_img[:,m,k];

                remaining_height -= nt_height[j]

    return logo.astype(np.uint8)

# %%
prediction = layers.get_output(deconv['output'], deterministic=False)
test_fun = theano.function([input_var2], prediction)

class_index = 17

labels = np.argmax(test[1],axis=1)
map_index = np.where(labels == class_index)[0]
for index in map_index[:20]:
    
    y = np.expand_dims(output2[index,:],0)
    prediction = test_fun(y.astype(np.float32))
    class_index = np.argmax(test[1][index,:])

    height=100
    bp_width=20
    size = (25.,10.0)

    logo = seq_logo(np.squeeze(test[0][index]), height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');

    logo = seq_logo(test[2][index], height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');
    plt.title(str(class_index),fontsize=20)

    logo = seq_logo(np.squeeze(prediction[0]), height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');
    plt.title(str(np.argmax(output2[index,:]))+'; p='+str(np.max(output2[index,:])),fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-e79d4b28f7f0> in <module>()
#      27     plt.title(str(class_index),fontsize=20)
#      28
# ---> 29     logo = seq_logo(np.squeeze(prediction[0]), height, bp_width, norm=0, rna=1, filepath='.')
#      30     fig = plt.figure(figsize=size);
#      31     plt.imshow(logo, interpolation='none');
#
# <ipython-input-16-b4c5281f4d1c> in seq_logo(pwm, height, nt_width, norm, rna, filepath)
#      91                     for k in range(3):
#      92                         for m in range(len(width_range)):
# ---> 93                             logo[height_range+offset, width_range[m],k] = nt_img[:,m,k];
#      94
#      95                 remaining_height -= nt_height[j]
#
# IndexError: index 252 is out of bounds for axis 0 with size 200

# %%
prediction = layers.get_output(deconv['output'], deterministic=False)
test_fun = theano.function([input_var2], prediction)


for index in range(40,60):

    y = np.expand_dims(output2[index,:],0)
    prediction = test_fun(y.astype(np.float32))
    class_index = np.argmax(test[1][index,:])

    height=100
    bp_width=20
    size = (25.,10.0)

    logo = seq_logo(np.squeeze(test[0][index]), height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');

    logo = seq_logo(test[2][index], height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');
    plt.title(str(class_index),fontsize=20)

    logo = seq_logo(np.squeeze(prediction[0]), height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');
    plt.title(str(np.argmax(output2[index,:]))+'; p='+str(np.max(output2[index,:])),fontsize=20)

# %%
savename = 'unlocalized'

# %%
def plot_conv_filter(layer,size):
    W =  np.squeeze(layer.W.get_value())
    num_filters = W.shape[0]

    num_rows = int(np.ceil(np.sqrt(num_filters)))    
    grid = mpl.gridspec.GridSpec(num_rows, num_rows)
    grid.update(wspace=0.2, hspace=0.2, left=0.1, right=0.2, bottom=0.1, top=0.2) 
    
    fig = plt.figure(figsize=size);
    for i in range(num_filters):
        MIN = np.min(W[i])
        MAX = np.max(W[i])
        pwm = (W[i] - MIN)#/(MAX-MIN)
        norm = np.outer(np.ones(4), np.sum(pwm, axis=0))
        pwm = pwm/norm

        logo = seq_logo(pwm, height=100, nt_width=25, norm=0, rna=1, filepath='.')
        plt.subplot(grid[i]);
        plt.imshow(logo);
        plt.axis('off');
    return fig, plt
# %config InlineBackend.close_figures = False
fig, plt = plot_conv_filter(network['conv1'],size=(100.,100.))
fig.set_size_inches(100,100)

outfile = savename +'_filter1.pdf'
fig.savefig(outfile, format='pdf', dpi=1000)  
call(['pdfcrop', outfile, outfile])

# %%
X = test[0]
input_var = nnmodel.input_var
layer = network['conv1_active']

# setup theano function to get feature map of a given layer
num_data = len(X)
feature_maps = theano.function([input_var], layers.get_output(layer), allow_input_downcast=True)
map_shape = get_output_shape(layer)

# get feature maps in batches for speed (large batches may be too much memory for GPU)
num_batches = num_data // batch_size
shape = list(map_shape)
shape[0] = num_data
fmaps = np.empty(tuple(shape))
for i in range(num_batches):
    index = range(i*batch_size, (i+1)*batch_size)    
    fmaps[index] = feature_maps(X[index])

# get the rest of the feature maps
excess = num_data-num_batches*batch_size
index = range(num_data-excess, num_data)    
fmaps[index] = feature_maps(X[index])

# %%
def get_class_activation(fmaps, y, batch_size=512):
    fmaps = np.squeeze(fmaps)
    mean_activation = []
    std_activation = []
    for i in range(max(y)+1):
        index = np.where(y == i)[0]
        mean_activation.append(np.mean(fmaps[index], axis=0))
        std_activation.append(np.std(fmaps[index], axis=0))
    return np.array(mean_activation), np.array(std_activation)


def plot_mean_activations(mean_activation, options):
    num_labels = len(mean_activation)
    nrows = np.ceil(np.sqrt(num_labels)).astype(int)
    ncols = nrows

    plt.figure()
    grid = mpl.gridspec.GridSpec(nrows, ncols)
    grid.update(wspace=0.2, hspace=0.2, left=0.1, right=0.2, bottom=0.1, top=0.2) 
    
    for i in range(num_labels):
        plt.subplot(grid[i])
        plt.plot(mean_activation[i].T)
        fig_options(plt, options)
    return plt

def fig_options(plt, options):
    if 'figsize' in options:
        fig = plt.gcf()
        fig.set_size_inches(options['figsize'][0], options['figsize'][1], forward=True)
    if 'ylim' in options:
        plt.ylim(options['ylim'][0],options['ylim'][1])
    if 'yticks' in options:
        plt.yticks(options['yticks'])
    if 'xticks' in options:
        plt.xticks(options['xticks'])
    if 'labelsize' in options:        
        ax = plt.gca()
        ax.tick_params(axis='x', labelsize=options['labelsize'])
        ax.tick_params(axis='y', labelsize=options['labelsize'])
    if 'axis' in options:
        plt.axis(options['axis'])
    if 'xlabel' in options:
        plt.xlabel(options['xlabel'], fontsize=options['fontsize'])
    if 'ylabel' in options:
        plt.ylabel(options['ylabel'], fontsize=options['fontsize'])
    if 'linewidth' in options:
        plt.rc('axes', linewidth=options['linewidth'])
        

        
mean_activation, std_activation = get_class_activation(fmaps, np.argmax(test[1],axis=1))
options = { 'ylim': [0, 4],
            'xticks': [0, 50, 100, 150],
            'yticks': [0.5, 1.5, 2.5, 3.5], 
            'labelsize': 18,
            'figsize': (150,100)}
plt = plot_mean_activations(mean_activation, options)
#plt.savefig('categorical_l1_activation.eps', format='eps', dpi=1000)
