# %%
import sys
import os
import numpy as np
sys.path.append('..')
from src import NeuralNet
from src import train as fit
from src import make_directory 
from models import load_model
from data import load_data
from six.moves import cPickle
from subprocess import call

np.random.seed(247) # for reproducibility

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib as mpl
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
# %matplotlib inline
from scipy.misc import imresize

from lasagne import layers, nonlinearities, updates, objectives, init 
from lasagne.layers import Conv2DLayer, TransposedConv2DLayer, DenseLayer, InputLayer, ExpressionLayer, BiasLayer

from lasagne.layers import get_output, get_output_shape, get_all_params
import theano.tensor as T
import theano
np.random.seed(247) # for reproducibility
# Out:
# Using gpu device 0: GeForce GTX 980 (CNMeM is disabled, CuDNN 4007)

# %%
filename = 'Localized_N=100000_S=200_M=50_G=20_data.pickle'
datapath = '/home/peter/Data/SequenceMotif'
filepath = os.path.join(datapath, filename)

# load training set
print "loading data from: " + filepath
f = open(filepath, 'rb')
print "loading train data"
train = cPickle.load(f)
print "loading cross-validation data"
cross_validation = cPickle.load(f)
print "loading test data"
test = cPickle.load(f)
f.close()

X_train = train[0].transpose((0,1,2)).astype(np.float32)
y_train = train[1].astype(np.int32)
X_val = cross_validation[0].transpose((0,1,2)).astype(np.float32)
y_val = cross_validation[1].astype(np.int32)
X_test = test[0].transpose((0,1,2)).astype(np.float32)
y_test = test[1].astype(np.int32)

X_train = np.expand_dims(X_train, axis=3)
X_val = np.expand_dims(X_val, axis=3)
X_test = np.expand_dims(X_test, axis=3)

train = (X_train, y_train, train[2])
valid = (X_val, y_val, cross_validation[2])
test = (X_test, y_test, test[2])

shape = (None, train[0].shape[1], train[0].shape[2], train[0].shape[3])
num_labels = train[1].shape[1]
# Out:
# loading data from: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle
# loading train data
# loading cross-validation data
# loading test data

# %%
model_name = "test_motif_model"
nnmodel = NeuralNet(model_name, shape, num_labels)

# %%
nnmodel = fit.train_minibatch(nnmodel, train, valid, batch_size=128, num_epochs=500, 
                        patience=2, verbose=1, filepath=filepath)
# Out:
# Epoch 1 out of 500
# [==============================] 100.0% -- time=0s -- loss=1.66823 -- accuracy=87.24%
#   valid loss:		1.22869
#   valid accuracy:	0.96115+/-0.02342
#   valid auc-roc:	0.86509+/-0.10678
#   valid auc-pr:		0.43378+/-0.31482
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_0.pickle
# Epoch 2 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.98965 -- accuracy=96.22%
#   valid loss:		0.73972
#   valid accuracy:	0.97194+/-0.01812
#   valid auc-roc:	0.94366+/-0.06709
#   valid auc-pr:		0.65976+/-0.28037
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_1.pickle
# Epoch 3 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.58012 -- accuracy=97.49%
#   valid loss:		0.43056
#   valid accuracy:	0.98251+/-0.01288
#   valid auc-roc:	0.97933+/-0.02761
#   valid auc-pr:		0.80999+/-0.26612
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_2.pickle
# Epoch 4 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35335 -- accuracy=98.50%
#   valid loss:		0.28629
#   valid accuracy:	0.98883+/-0.00969
#   valid auc-roc:	0.99168+/-0.01081
#   valid auc-pr:		0.88299+/-0.22081
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_3.pickle
# Epoch 5 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.25737 -- accuracy=99.03%
#   valid loss:		0.23120
#   valid accuracy:	0.99243+/-0.00739
#   valid auc-roc:	0.99538+/-0.00671
#   valid auc-pr:		0.92037+/-0.16862
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_4.pickle
# Epoch 6 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.21598 -- accuracy=99.29%
#   valid loss:		0.19983
#   valid accuracy:	0.99342+/-0.00638
#   valid auc-roc:	0.99653+/-0.00583
#   valid auc-pr:		0.93380+/-0.14981
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_5.pickle
# Epoch 7 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.18923 -- accuracy=99.44%
#   valid loss:		0.17718
#   valid accuracy:	0.99464+/-0.00469
#   valid auc-roc:	0.99749+/-0.00446
#   valid auc-pr:		0.94507+/-0.12982
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_6.pickle
# Epoch 8 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.16898 -- accuracy=99.53%
#   valid loss:		0.15995
#   valid accuracy:	0.99524+/-0.00438
#   valid auc-roc:	0.99849+/-0.00207
#   valid auc-pr:		0.94972+/-0.12686
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_7.pickle
# Epoch 9 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.15392 -- accuracy=99.58%
#   valid loss:		0.14710
#   valid accuracy:	0.99503+/-0.00494
#   valid auc-roc:	0.99852+/-0.00220
#   valid auc-pr:		0.94105+/-0.15425
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_8.pickle
# Epoch 10 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.14257 -- accuracy=99.63%
#   valid loss:		0.13703
#   valid accuracy:	0.99571+/-0.00455
#   valid auc-roc:	0.99891+/-0.00148
#   valid auc-pr:		0.95681+/-0.11196
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_9.pickle
# Epoch 11 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.13394 -- accuracy=99.65%
#   valid loss:		0.12899
#   valid accuracy:	0.99643+/-0.00344
#   valid auc-roc:	0.99899+/-0.00146
#   valid auc-pr:		0.96727+/-0.08642
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_10.pickle
# Epoch 12 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.12688 -- accuracy=99.67%
#   valid loss:		0.12258
#   valid accuracy:	0.99645+/-0.00334
#   valid auc-roc:	0.99938+/-0.00087
#   valid auc-pr:		0.98111+/-0.04977
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_11.pickle
# Epoch 13 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.12058 -- accuracy=99.68%
#   valid loss:		0.11899
#   valid accuracy:	0.99674+/-0.00346
#   valid auc-roc:	0.99943+/-0.00080
#   valid auc-pr:		0.98815+/-0.02040
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_12.pickle
# Epoch 14 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.11534 -- accuracy=99.67%
#   valid loss:		0.11163
#   valid accuracy:	0.99648+/-0.00332
#   valid auc-roc:	0.99941+/-0.00080
#   valid auc-pr:		0.98776+/-0.02224
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_13.pickle
# Epoch 15 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.11040 -- accuracy=99.67%
#   valid loss:		0.10811
#   valid accuracy:	0.99636+/-0.00407
#   valid auc-roc:	0.99942+/-0.00086
#   valid auc-pr:		0.98497+/-0.03328
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_14.pickle
# Epoch 16 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.10590 -- accuracy=99.66%
#   valid loss:		0.10232
#   valid accuracy:	0.99618+/-0.00402
#   valid auc-roc:	0.99945+/-0.00082
#   valid auc-pr:		0.98764+/-0.02391
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_15.pickle
# Epoch 17 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.10141 -- accuracy=99.66%
#   valid loss:		0.09800
#   valid accuracy:	0.99605+/-0.00413
#   valid auc-roc:	0.99941+/-0.00088
#   valid auc-pr:		0.98879+/-0.01816
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_16.pickle
# Epoch 18 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.09760 -- accuracy=99.65%
#   valid loss:		0.09404
#   valid accuracy:	0.99659+/-0.00308
#   valid auc-roc:	0.99934+/-0.00090
#   valid auc-pr:		0.98684+/-0.02420
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_17.pickle
# Epoch 19 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.09425 -- accuracy=99.64%
#   valid loss:		0.09170
#   valid accuracy:	0.99662+/-0.00325
#   valid auc-roc:	0.99943+/-0.00086
#   valid auc-pr:		0.98946+/-0.01640
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_18.pickle
# Epoch 20 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.09125 -- accuracy=99.64%
#   valid loss:		0.08810
#   valid accuracy:	0.99649+/-0.00336
#   valid auc-roc:	0.99947+/-0.00077
#   valid auc-pr:		0.99060+/-0.01360
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_19.pickle
# Epoch 21 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08866 -- accuracy=99.63%
#   valid loss:		0.08597
#   valid accuracy:	0.99643+/-0.00402
#   valid auc-roc:	0.99947+/-0.00076
#   valid auc-pr:		0.99038+/-0.01397
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_20.pickle
# Epoch 22 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08630 -- accuracy=99.63%
#   valid loss:		0.08299
#   valid accuracy:	0.99637+/-0.00348
#   valid auc-roc:	0.99949+/-0.00075
#   valid auc-pr:		0.98805+/-0.02030
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_21.pickle
# Epoch 23 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08410 -- accuracy=99.64%
#   valid loss:		0.08074
#   valid accuracy:	0.99646+/-0.00345
#   valid auc-roc:	0.99947+/-0.00080
#   valid auc-pr:		0.98959+/-0.01656
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_22.pickle
# Epoch 24 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.08204 -- accuracy=99.63%
#   valid loss:		0.07910
#   valid accuracy:	0.99664+/-0.00319
#   valid auc-roc:	0.99946+/-0.00076
#   valid auc-pr:		0.98804+/-0.01986
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_23.pickle
# Epoch 25 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07993 -- accuracy=99.64%
#   valid loss:		0.07684
#   valid accuracy:	0.99656+/-0.00323
#   valid auc-roc:	0.99949+/-0.00070
#   valid auc-pr:		0.98717+/-0.02336
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_24.pickle
# Epoch 26 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07786 -- accuracy=99.65%
#   valid loss:		0.07464
#   valid accuracy:	0.99662+/-0.00340
#   valid auc-roc:	0.99939+/-0.00085
#   valid auc-pr:		0.98944+/-0.01699
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_25.pickle
# Epoch 27 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07592 -- accuracy=99.64%
#   valid loss:		0.07298
#   valid accuracy:	0.99656+/-0.00325
#   valid auc-roc:	0.99946+/-0.00078
#   valid auc-pr:		0.98906+/-0.01787
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_26.pickle
# Epoch 28 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07402 -- accuracy=99.65%
#   valid loss:		0.07073
#   valid accuracy:	0.99657+/-0.00358
#   valid auc-roc:	0.99955+/-0.00063
#   valid auc-pr:		0.98761+/-0.02369
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_27.pickle
# Epoch 29 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07256 -- accuracy=99.65%
#   valid loss:		0.06921
#   valid accuracy:	0.99665+/-0.00326
#   valid auc-roc:	0.99947+/-0.00071
#   valid auc-pr:		0.98521+/-0.03002
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_28.pickle
# Epoch 30 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.07085 -- accuracy=99.66%
#   valid loss:		0.06742
#   valid accuracy:	0.99663+/-0.00334
#   valid auc-roc:	0.99957+/-0.00062
#   valid auc-pr:		0.98855+/-0.02087
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_29.pickle
# Epoch 31 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06945 -- accuracy=99.66%
#   valid loss:		0.06615
#   valid accuracy:	0.99681+/-0.00310
#   valid auc-roc:	0.99949+/-0.00067
#   valid auc-pr:		0.98762+/-0.02336
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_30.pickle
# Epoch 32 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06792 -- accuracy=99.67%
#   valid loss:		0.06456
#   valid accuracy:	0.99677+/-0.00301
#   valid auc-roc:	0.99956+/-0.00060
#   valid auc-pr:		0.98921+/-0.02093
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_31.pickle
# Epoch 33 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06656 -- accuracy=99.68%
#   valid loss:		0.06327
#   valid accuracy:	0.99686+/-0.00317
#   valid auc-roc:	0.99954+/-0.00064
#   valid auc-pr:		0.98900+/-0.02071
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_32.pickle
# Epoch 34 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06545 -- accuracy=99.67%
#   valid loss:		0.06224
#   valid accuracy:	0.99690+/-0.00314
#   valid auc-roc:	0.99949+/-0.00073
#   valid auc-pr:		0.98611+/-0.02803
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_33.pickle
# Epoch 35 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06416 -- accuracy=99.68%
#   valid loss:		0.06101
#   valid accuracy:	0.99691+/-0.00306
#   valid auc-roc:	0.99954+/-0.00063
#   valid auc-pr:		0.98694+/-0.02575
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_34.pickle
# Epoch 36 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06312 -- accuracy=99.68%
#   valid loss:		0.05975
#   valid accuracy:	0.99704+/-0.00274
#   valid auc-roc:	0.99955+/-0.00059
#   valid auc-pr:		0.98988+/-0.01754
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_35.pickle
# Epoch 37 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06212 -- accuracy=99.69%
#   valid loss:		0.05909
#   valid accuracy:	0.99698+/-0.00317
#   valid auc-roc:	0.99950+/-0.00067
#   valid auc-pr:		0.98690+/-0.02665
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_36.pickle
# Epoch 38 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06099 -- accuracy=99.69%
#   valid loss:		0.05801
#   valid accuracy:	0.99696+/-0.00271
#   valid auc-roc:	0.99953+/-0.00064
#   valid auc-pr:		0.98816+/-0.02213
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_37.pickle
# Epoch 39 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.06018 -- accuracy=99.69%
#   valid loss:		0.05710
#   valid accuracy:	0.99707+/-0.00282
#   valid auc-roc:	0.99947+/-0.00071
#   valid auc-pr:		0.98844+/-0.02303
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_38.pickle
# Epoch 40 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05940 -- accuracy=99.69%
#   valid loss:		0.05638
#   valid accuracy:	0.99682+/-0.00300
#   valid auc-roc:	0.99954+/-0.00062
#   valid auc-pr:		0.98830+/-0.02347
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_39.pickle
# Epoch 41 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05847 -- accuracy=99.69%
#   valid loss:		0.05544
#   valid accuracy:	0.99702+/-0.00281
#   valid auc-roc:	0.99956+/-0.00062
#   valid auc-pr:		0.98942+/-0.02116
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_40.pickle
# Epoch 42 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05777 -- accuracy=99.69%
#   valid loss:		0.05455
#   valid accuracy:	0.99716+/-0.00275
#   valid auc-roc:	0.99938+/-0.00099
#   valid auc-pr:		0.98740+/-0.02584
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_41.pickle
# Epoch 43 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05701 -- accuracy=99.70%
#   valid loss:		0.05412
#   valid accuracy:	0.99710+/-0.00277
#   valid auc-roc:	0.99950+/-0.00072
#   valid auc-pr:		0.98687+/-0.02901
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_42.pickle
# Epoch 44 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05633 -- accuracy=99.70%
#   valid loss:		0.05339
#   valid accuracy:	0.99705+/-0.00285
#   valid auc-roc:	0.99949+/-0.00070
#   valid auc-pr:		0.98662+/-0.02754
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_43.pickle
# Epoch 45 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05570 -- accuracy=99.70%
#   valid loss:		0.05284
#   valid accuracy:	0.99706+/-0.00303
#   valid auc-roc:	0.99948+/-0.00071
#   valid auc-pr:		0.98752+/-0.02573
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_44.pickle
# Epoch 46 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05514 -- accuracy=99.71%
#   valid loss:		0.05258
#   valid accuracy:	0.99698+/-0.00308
#   valid auc-roc:	0.99941+/-0.00090
#   valid auc-pr:		0.98819+/-0.02267
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_45.pickle
# Epoch 47 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05457 -- accuracy=99.70%
#   valid loss:		0.05176
#   valid accuracy:	0.99720+/-0.00284
#   valid auc-roc:	0.99950+/-0.00063
#   valid auc-pr:		0.98573+/-0.02957
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_46.pickle
# Epoch 48 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05404 -- accuracy=99.70%
#   valid loss:		0.05145
#   valid accuracy:	0.99707+/-0.00286
#   valid auc-roc:	0.99947+/-0.00071
#   valid auc-pr:		0.98577+/-0.02998
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_47.pickle
# Epoch 49 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05382 -- accuracy=99.70%
#   valid loss:		0.05089
#   valid accuracy:	0.99704+/-0.00289
#   valid auc-roc:	0.99952+/-0.00065
#   valid auc-pr:		0.98870+/-0.02249
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_48.pickle
# Epoch 50 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05336 -- accuracy=99.71%
#   valid loss:		0.05028
#   valid accuracy:	0.99724+/-0.00273
#   valid auc-roc:	0.99950+/-0.00069
#   valid auc-pr:		0.98776+/-0.02433
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_49.pickle
# Epoch 51 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05295 -- accuracy=99.71%
#   valid loss:		0.05008
#   valid accuracy:	0.99720+/-0.00272
#   valid auc-roc:	0.99947+/-0.00077
#   valid auc-pr:		0.98599+/-0.02981
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_50.pickle
# Epoch 52 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05261 -- accuracy=99.71%
#   valid loss:		0.05027
#   valid accuracy:	0.99700+/-0.00317
#   valid auc-roc:	0.99949+/-0.00069
#   valid auc-pr:		0.98610+/-0.02843
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_51.pickle
# Epoch 53 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05247 -- accuracy=99.71%
#   valid loss:		0.04980
#   valid accuracy:	0.99710+/-0.00272
#   valid auc-roc:	0.99929+/-0.00116
#   valid auc-pr:		0.98686+/-0.02656
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_52.pickle
# Epoch 54 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05207 -- accuracy=99.71%
#   valid loss:		0.04939
#   valid accuracy:	0.99705+/-0.00287
#   valid auc-roc:	0.99943+/-0.00071
#   valid auc-pr:		0.98746+/-0.02509
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_53.pickle
# Epoch 55 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05186 -- accuracy=99.71%
#   valid loss:		0.04933
#   valid accuracy:	0.99706+/-0.00278
#   valid auc-roc:	0.99936+/-0.00097
#   valid auc-pr:		0.98309+/-0.03739
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_54.pickle
# Epoch 56 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05161 -- accuracy=99.71%
#   valid loss:		0.04855
#   valid accuracy:	0.99730+/-0.00273
#   valid auc-roc:	0.99942+/-0.00079
#   valid auc-pr:		0.98250+/-0.03994
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_55.pickle
# Epoch 57 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05135 -- accuracy=99.71%
#   valid loss:		0.04850
#   valid accuracy:	0.99713+/-0.00268
#   valid auc-roc:	0.99948+/-0.00069
#   valid auc-pr:		0.98448+/-0.03382
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_56.pickle
# Epoch 58 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05102 -- accuracy=99.71%
#   valid loss:		0.04824
#   valid accuracy:	0.99716+/-0.00262
#   valid auc-roc:	0.99950+/-0.00062
#   valid auc-pr:		0.98535+/-0.03089
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_57.pickle
# Epoch 59 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05094 -- accuracy=99.71%
#   valid loss:		0.04813
#   valid accuracy:	0.99722+/-0.00268
#   valid auc-roc:	0.99950+/-0.00061
#   valid auc-pr:		0.98495+/-0.03184
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_58.pickle
# Epoch 60 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05060 -- accuracy=99.71%
#   valid loss:		0.04786
#   valid accuracy:	0.99718+/-0.00285
#   valid auc-roc:	0.99946+/-0.00074
#   valid auc-pr:		0.98424+/-0.03396
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_59.pickle
# Epoch 61 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05041 -- accuracy=99.71%
#   valid loss:		0.04799
#   valid accuracy:	0.99707+/-0.00269
#   valid auc-roc:	0.99948+/-0.00071
#   valid auc-pr:		0.98394+/-0.03549
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_60.pickle
# Epoch 62 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05022 -- accuracy=99.71%
#   valid loss:		0.04745
#   valid accuracy:	0.99726+/-0.00277
#   valid auc-roc:	0.99938+/-0.00094
#   valid auc-pr:		0.98262+/-0.03954
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_61.pickle
# Epoch 63 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04998 -- accuracy=99.71%
#   valid loss:		0.04754
#   valid accuracy:	0.99705+/-0.00285
#   valid auc-roc:	0.99936+/-0.00107
#   valid auc-pr:		0.98455+/-0.03343
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_62.pickle
# Epoch 64 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.05000 -- accuracy=99.70%
#   valid loss:		0.04701
#   valid accuracy:	0.99721+/-0.00275
#   valid auc-roc:	0.99941+/-0.00077
#   valid auc-pr:		0.98581+/-0.02936
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_63.pickle
# Epoch 65 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04981 -- accuracy=99.70%
#   valid loss:		0.04740
#   valid accuracy:	0.99706+/-0.00295
#   valid auc-roc:	0.99942+/-0.00081
#   valid auc-pr:		0.98590+/-0.02924
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_64.pickle
# Epoch 66 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04960 -- accuracy=99.70%
#   valid loss:		0.04701
#   valid accuracy:	0.99714+/-0.00298
#   valid auc-roc:	0.99947+/-0.00073
#   valid auc-pr:		0.98329+/-0.03684
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_65.pickle
# Epoch 67 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04949 -- accuracy=99.70%
#   valid loss:		0.04688
#   valid accuracy:	0.99707+/-0.00280
#   valid auc-roc:	0.99945+/-0.00075
#   valid auc-pr:		0.98208+/-0.04130
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_66.pickle
# Epoch 68 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04947 -- accuracy=99.70%
#   valid loss:		0.04651
#   valid accuracy:	0.99724+/-0.00260
#   valid auc-roc:	0.99949+/-0.00069
#   valid auc-pr:		0.98382+/-0.03619
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_67.pickle
# Epoch 69 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04917 -- accuracy=99.70%
#   valid loss:		0.04658
#   valid accuracy:	0.99713+/-0.00287
#   valid auc-roc:	0.99935+/-0.00092
#   valid auc-pr:		0.98470+/-0.03319
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_68.pickle
# Epoch 70 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04897 -- accuracy=99.71%
#   valid loss:		0.04645
#   valid accuracy:	0.99719+/-0.00279
#   valid auc-roc:	0.99948+/-0.00063
#   valid auc-pr:		0.98488+/-0.03213
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_69.pickle
# Epoch 71 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04894 -- accuracy=99.71%
#   valid loss:		0.04609
#   valid accuracy:	0.99715+/-0.00280
#   valid auc-roc:	0.99948+/-0.00066
#   valid auc-pr:		0.98459+/-0.03352
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_70.pickle
# Epoch 72 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04882 -- accuracy=99.70%
#   valid loss:		0.04592
#   valid accuracy:	0.99704+/-0.00290
#   valid auc-roc:	0.99948+/-0.00064
#   valid auc-pr:		0.98428+/-0.03450
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_71.pickle
# Epoch 73 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04858 -- accuracy=99.71%
#   valid loss:		0.04590
#   valid accuracy:	0.99713+/-0.00263
#   valid auc-roc:	0.99941+/-0.00070
#   valid auc-pr:		0.97978+/-0.04844
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_72.pickle
# Epoch 74 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04842 -- accuracy=99.71%
#   valid loss:		0.04592
#   valid accuracy:	0.99705+/-0.00283
#   valid auc-roc:	0.99936+/-0.00092
#   valid auc-pr:		0.98162+/-0.04177
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_73.pickle
# Epoch 75 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04836 -- accuracy=99.71%
#   valid loss:		0.04544
#   valid accuracy:	0.99727+/-0.00277
#   valid auc-roc:	0.99940+/-0.00074
#   valid auc-pr:		0.98075+/-0.04440
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_74.pickle
# Epoch 76 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04810 -- accuracy=99.71%
#   valid loss:		0.04531
#   valid accuracy:	0.99716+/-0.00278
#   valid auc-roc:	0.99935+/-0.00089
#   valid auc-pr:		0.98482+/-0.03268
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_75.pickle
# Epoch 77 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04803 -- accuracy=99.71%
#   valid loss:		0.04542
#   valid accuracy:	0.99711+/-0.00299
#   valid auc-roc:	0.99913+/-0.00174
#   valid auc-pr:		0.98275+/-0.03943
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_76.pickle
# Epoch 78 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04794 -- accuracy=99.71%
#   valid loss:		0.04506
#   valid accuracy:	0.99725+/-0.00265
#   valid auc-roc:	0.99942+/-0.00077
#   valid auc-pr:		0.98198+/-0.04062
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_77.pickle
# Epoch 79 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04777 -- accuracy=99.71%
#   valid loss:		0.04507
#   valid accuracy:	0.99719+/-0.00292
#   valid auc-roc:	0.99942+/-0.00072
#   valid auc-pr:		0.98109+/-0.04636
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_78.pickle
# Epoch 80 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04774 -- accuracy=99.70%
#   valid loss:		0.04544
#   valid accuracy:	0.99708+/-0.00265
#   valid auc-roc:	0.99942+/-0.00072
#   valid auc-pr:		0.98401+/-0.03422
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_79.pickle
# Epoch 81 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.04765 -- accuracy=99.70%
#   valid loss:		0.04512
#   valid accuracy:	0.99712+/-0.00289
#   valid auc-roc:	0.99941+/-0.00073
#   valid auc-pr:		0.98093+/-0.04463
# saving model parameters to: /home/peter/Data/SequenceMotif/Localized_N=100000_S=200_M=50_G=20_data.pickle_epoch_80.pickle
# Patience ran out... Early stopping.

# %%
#epoch = 111
#savepath = filepath + "_epoch_" + str(epoch) + ".pickle"
#nnmodel.set_parameters_from_file(savepath)

# %%
network = nnmodel.network
network
# Out:
# {'conv1': <lasagne.layers.dnn.Conv2DDNNLayer at 0x7f04f8c54490>,
#  'conv1_active': <lasagne.layers.special.ParametricRectifierLayer at 0x7f048f4a2b50>,
#  'conv1_batch': <lasagne.layers.normalization.BatchNormLayer at 0x7f04f8c49990>,
#  'conv1_bias': <lasagne.layers.special.BiasLayer at 0x7f04f8c49710>,
#  'conv1_pool': <lasagne.layers.pool.MaxPool2DLayer at 0x7f0495614e90>,
#  'conv2': <lasagne.layers.dnn.Conv2DDNNLayer at 0x7f048f4a2b90>,
#  'conv2_active': <lasagne.layers.special.ParametricRectifierLayer at 0x7f048f4ad590>,
#  'conv2_batch': <lasagne.layers.normalization.BatchNormLayer at 0x7f048f4a2e90>,
#  'conv2_bias': <lasagne.layers.special.BiasLayer at 0x7f048f4a2d50>,
#  'conv2_pool': <lasagne.layers.pool.MaxPool2DLayer at 0x7f048f4ad050>,
#  'dense1': <lasagne.layers.dense.DenseLayer at 0x7f048f4ad5d0>,
#  'dense1_active': <lasagne.layers.special.ParametricRectifierLayer at 0x7f048f4b73d0>,
#  'dense1_batch': <lasagne.layers.normalization.BatchNormLayer at 0x7f048f4adc50>,
#  'dense1_bias': <lasagne.layers.special.BiasLayer at 0x7f048f4ad790>,
#  'dense1_dropout': <lasagne.layers.noise.DropoutLayer at 0x7f048f4ade10>,
#  'dense2': <lasagne.layers.dense.DenseLayer at 0x7f048f4b7610>,
#  'dense2_active': <lasagne.layers.special.NonlinearityLayer at 0x7f048f4b7790>,
#  'dense2_bias': <lasagne.layers.special.BiasLayer at 0x7f048f4b7650>,
#  'input': <lasagne.layers.input.InputLayer at 0x7f04f8c54410>,
#  'output': <lasagne.layers.special.NonlinearityLayer at 0x7f048f4b7790>}

# %%
def get_output(X,layer):
    num_data = len(X)
    feature_maps = theano.function([nnmodel.input_var], layers.get_output(layer,deterministic=True), allow_input_downcast=True)
    map_shape = get_output_shape(layer)

    # get feature maps in batches for speed (large batches may be too much memory for GPU)
    batch_size=500
    num_batches = num_data // batch_size
    shape = list(map_shape)
    shape[0] = num_data
    output = np.empty(tuple(shape))
    for i in range(num_batches):
        index = range(i*batch_size, (i+1)*batch_size)    
        output[index] = feature_maps(X[index])

    # get the rest of the feature maps
    excess = num_data-num_batches*batch_size
    if excess:
        index = range(num_data-excess, num_data)  
        output[index] = feature_maps(X[index])
    return output


X = train[0]
layer = network['output']
output = get_output(X,layer)
output2 = get_output(test[0],layer)

# %%
output2
# Out:
# array([[  2.27890079e-04,   1.09079665e-05,   9.98265088e-01, ...,
#           9.70106339e-05,   2.03117059e-04,   3.32466036e-04],
#        [  2.65502807e-04,   1.13961658e-04,   8.17449181e-05, ...,
#           2.71254947e-04,   9.99986649e-01,   3.86221684e-04],
#        [  1.34401052e-04,   2.76093534e-03,   1.16569339e-04, ...,
#           9.93068576e-01,   2.34007268e-04,   2.26227203e-04],
#        ...,
#        [  1.34600225e-04,   7.24425399e-06,   1.07273030e-04, ...,
#           9.99925494e-01,   3.17411977e-05,   1.08127068e-04],
#        [  2.36194610e-04,   3.51836716e-05,   8.52147932e-04, ...,
#           6.52993549e-05,   5.97785984e-05,   5.51022997e-04],
#        [  7.45143683e-04,   3.68088624e-03,   9.14978373e-05, ...,
#           5.29695535e-03,   3.99942946e-04,   1.31058076e-03]])

# %%
shape2 = list(output.shape)
shape2[0] = None
input_var2 = T.dmatrix('input')
input_var2 = T.cast(input_var2, 'float32')


deconv = {}
deconv['input'] = InputLayer(tuple(shape2), input_var=input_var2)
num_units = list(get_output_shape(network['dense1']))[1]
deconv['dense2'] = layers.DenseLayer(deconv['input'], num_units=num_units, W=network['dense2'].W.dimshuffle([1,0]), 
                                     b=init.Constant(0.05), nonlinearity=None)
#deconv['dense2'].params[deconv['dense2'].W].remove('trainable')
#deconv['dense2_norm'] = layers.BatchNormLayer(deconv['dense2'])
#deconv['dense2_active'] = layers.ParametricRectifierLayer(deconv['dense2'], alpha=init.Constant(0.25))
deconv['dense2_active'] = layers.NonlinearityLayer(deconv['dense2'], nonlinearity=nonlinearities.rectify)

num_units = np.prod(list(get_output_shape(network['conv2_pool']))[1:])
deconv['dense1'] = layers.DenseLayer(deconv['dense2_active'], num_units=num_units, W=network['dense1'].W.dimshuffle([1,0]), 
                                     b=init.Constant(0.05), nonlinearity=None)
#deconv['dense1'].params[deconv['dense1'].W].remove('trainable')
#deconv['dense1_norm'] = layers.BatchNormLayer(deconv['dense1'])
#deconv['dense1_active'] = layers.ParametricRectifierLayer(deconv['dense1'], alpha=init.Constant(0.25))
deconv['dense1_active'] = layers.NonlinearityLayer(deconv['dense1'], nonlinearity=nonlinearities.rectify)

shape = list(get_output_shape(network['conv2_pool']))
shape[0] = -1
deconv['reshape'] = layers.ReshapeLayer(deconv['dense1_active'], shape=tuple(shape))
deconv['pool2'] = layers.Upscale2DLayer(deconv['reshape'], (5,1))
deconv['conv2']  = Conv2DLayer(deconv['pool2'], num_filters=network['conv2'].input_shape[1],
                                          filter_size=network['conv2'].filter_size,
                                          W=network['conv2'].W.dimshuffle([1,0,2,3]), #W2_inv, #
                                          b=init.Constant(0.05), 
                                          pad='same',
                                          nonlinearity=None, flip_filters=True)
#deconv['conv2'].params[deconv['conv2'].W].remove('trainable')
#deconv['conv2_norm'] = layers.BatchNormLayer(deconv['conv2'])
#deconv['conv2_active'] = layers.ParametricRectifierLayer(deconv['conv2'], alpha=init.Constant(0.25))
deconv['conv2_active'] = layers.NonlinearityLayer(deconv['conv2'], nonlinearity=nonlinearities.rectify)


deconv['pool1'] = layers.Upscale2DLayer(deconv['conv2_active'], (4,1))
deconv['conv1']  = Conv2DLayer(deconv['pool1'], num_filters=network['conv1'].input_shape[1],
                                          filter_size=network['conv1'].filter_size,
                                          W=network['conv1'].W.dimshuffle([1,0,2,3]), #W2_inv, #
                                          b=init.Constant(0.05), 
                                          pad='same',
                                          nonlinearity=None, flip_filters=True)
#deconv['conv1'].params[deconv['conv1'].W].remove('trainable')
#deconv['conv1_norm'] = layers.BatchNormLayer(deconv['conv1'])
deconv['conv1_active'] = layers.NonlinearityLayer(deconv['conv1'], nonlinearity=nonlinearities.sigmoid)

deconv['output'] = deconv['conv1_active']

# %%
from lasagne import updates, regularization

target_var = T.tensor4('targets')
prediction = layers.get_output(deconv['output'], deterministic=False)

loss = objectives.squared_error(prediction, target_var)
loss = objectives.aggregate(loss, mode='mean')

params = layers.get_all_params(deconv['output'], trainable=True)    
#l1_penalty = regularization.apply_penalty(params, regularization.l1)*1e-4
#l2_penalty = regularization.apply_penalty(params, regularization.l2)*1e-6
#loss = loss + l1_penalty + l2_penalty

grad = T.grad(loss, params)

#update_op = updates.adagrad(grad, params, learning_rate=0.001)
update_op = updates.adam(grad, params, learning_rate=0.0001)
#update_op = updates.nesterov_momentum(grad, params, learning_rate=0.001, momentum=0.9)

train_fun = theano.function([input_var2, target_var], [loss, prediction], updates=update_op)

# %%
def batch_generator(X, y, batch_size=128):
    for start_idx in range(0, len(X)-batch_size+1, batch_size):
        excerpt = slice(start_idx, start_idx+batch_size)
        yield X[excerpt].astype(np.float32), y[excerpt].astype(np.float32)

batch_size = 128        
for epoch in range(50):
    sys.stdout.write("\rEpoch %d \n"%(epoch+1))

    num_batches = output.shape[0] // batch_size
    batches = batch_generator(output, train[0], batch_size)
    value = 0
    for i in range(num_batches):
        X,y = next(batches)
        loss, prediction = train_fun(X, y)
        value += np.mean(loss)
    sys.stdout.write("\r  loss = %f \n"%(value/num_batches))
# Out:
# Epoch 1
#   loss = 0.250567
# Epoch 2
#   loss = 0.239843
# Epoch 3
#   loss = 0.230578
# Epoch 4
#   loss = 0.222679
# Epoch 5
#   loss = 0.216039
# Epoch 6
#   loss = 0.210524
# Epoch 7
#   loss = 0.205992
# Epoch 8
#   loss = 0.202305
# Epoch 9
#   loss = 0.199338
# Epoch 10
#   loss = 0.196979
# Epoch 11
#   loss = 0.195128
# Epoch 12
#   loss = 0.193695
# Epoch 13
#   loss = 0.192588
# Epoch 14
#   loss = 0.191673
# Epoch 15
#   loss = 0.190978
# Epoch 16
#   loss = 0.190441
# Epoch 17
#   loss = 0.189993
# Epoch 18
#   loss = 0.189512
# Epoch 19
#   loss = 0.189074
# Epoch 20
#   loss = 0.188673
# Epoch 21
#   loss = 0.188280
# Epoch 22
#   loss = 0.188075
# Epoch 23
#   loss = 0.187954
# Epoch 24
#   loss = 0.187866
# Epoch 25
#   loss = 0.187791
# Epoch 26
#   loss = 0.187725
# Epoch 27
#   loss = 0.187668
# Epoch 28
#   loss = 0.187620
# Epoch 29
#   loss = 0.187581
# Epoch 30
#   loss = 0.187550
# Epoch 31
#   loss = 0.187527
# Epoch 32
#   loss = 0.187510
# Epoch 33
#   loss = 0.187498
# Epoch 34
#   loss = 0.187489
# Epoch 35
#   loss = 0.187484
# Epoch 36
#   loss = 0.187480
# Epoch 37
#   loss = 0.187478
# Epoch 38
#   loss = 0.187477
# Epoch 39
#   loss = 0.187476
# Epoch 40
#   loss = 0.187476
# Epoch 41
#   loss = 0.187476
# Epoch 42
#   loss = 0.187476
# Epoch 43
#   loss = 0.187476
# Epoch 44
#   loss = 0.187475
# Epoch 45
#   loss = 0.187475
# Epoch 46
#   loss = 0.187475
# Epoch 47
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-d16b5cfa09f9> in <module>()
#      13     for i in range(num_batches):
#      14         X,y = next(batches)
# ---> 15         loss, prediction = train_fun(X, y)
#      16         value += np.mean(loss)
#      17     sys.stdout.write("\r  loss = %f \n"%(value/num_batches))
#
# /home/peter/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /home/peter/anaconda2/lib/python2.7/site-packages/theano/gof/op.pyc in rval(p, i, o, n)
#     909         if params is graph.NoParams:
#     910             # default arguments are stored in the closure of `rval`
# --> 911             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     912                 r = p(n, [x[0] for x in i], o)
#     913                 for o in node.outputs:
#
# KeyboardInterrupt:

# %%
def seq_logo(pwm, height=100, nt_width=20, norm=0, rna=1, filepath='.'):
    """generate a sequence logo from a pwm"""
    
    def load_alphabet(filepath, rna):
        """load images of nucleotide alphabet """
        df = pd.read_table(os.path.join(filepath, 'A.txt'), header=None);
        A_img = df.as_matrix()
        A_img = np.reshape(A_img, [72, 65, 3], order="F").astype(np.uint8)

        df = pd.read_table(os.path.join(filepath, 'C.txt'), header=None);
        C_img = df.as_matrix()
        C_img = np.reshape(C_img, [76, 64, 3], order="F").astype(np.uint8)

        df = pd.read_table(os.path.join(filepath, 'G.txt'), header=None);
        G_img = df.as_matrix()
        G_img = np.reshape(G_img, [76, 67, 3], order="F").astype(np.uint8)

        if rna == 1:
            df = pd.read_table(os.path.join(filepath, 'U.txt'), header=None);
            T_img = df.as_matrix()
            T_img = np.reshape(T_img, [74, 57, 3], order="F").astype(np.uint8)
        else:
            df = pd.read_table(os.path.join(filepath, 'T.txt'), header=None);
            T_img = df.as_matrix()
            T_img = np.reshape(T_img, [72, 59, 3], order="F").astype(np.uint8)

        return A_img, C_img, G_img, T_img


    def get_nt_height(pwm, height, norm):
        """get the heights of each nucleotide"""

        def entropy(p):
            """calculate entropy of each nucleotide"""
            s = 0
            for i in range(4):
                if p[i] > 0:
                    s -= p[i]*np.log2(p[i])
            return s

        num_nt, num_seq = pwm.shape
        heights = np.zeros((num_nt,num_seq));
        for i in range(num_seq):
            if norm == 1:
                total_height = height
            else:
                total_height = (np.log2(4) - entropy(pwm[:, i]))*height;
            heights[:,i] = np.floor(pwm[:,i]*total_height);
        return heights.astype(int)

    
    # get the alphabet images of each nucleotide
    A_img, C_img, G_img, T_img = load_alphabet(filepath='.', rna=1)
    
    
    # get the heights of each nucleotide
    heights = get_nt_height(pwm, height, norm)
    
    # resize nucleotide images for each base of sequence and stack
    num_nt, num_seq = pwm.shape
    width = np.ceil(nt_width*num_seq).astype(int)
    
    total_height = np.sum(heights,axis=0)
    max_height = np.max(total_height)
    logo = np.ones((height*2, width, 3)).astype(int)*255;
    for i in range(num_seq):
        remaining_height = total_height[i];
        offset = max_height-remaining_height
        nt_height = np.sort(heights[:,i]);
        index = np.argsort(heights[:,i])

        for j in range(num_nt):
            if nt_height[j] > 0:
                # resized dimensions of image
                resize = (nt_height[j], nt_width)
                if index[j] == 0:
                    nt_img = imresize(A_img, resize)
                elif index[j] == 1:
                    nt_img = imresize(C_img, resize)
                elif index[j] == 2:
                    nt_img = imresize(G_img, resize)
                elif index[j] == 3:
                    nt_img = imresize(T_img, resize)

                # determine location of image
                height_range = range(remaining_height-nt_height[j], remaining_height)
                width_range = range(i*nt_width, i*nt_width+nt_width)

                # 'annoying' way to broadcast resized nucleotide image
                if height_range:
                    for k in range(3):
                        for m in range(len(width_range)):
                            logo[height_range+offset, width_range[m],k] = nt_img[:,m,k];

                remaining_height -= nt_height[j]

    return logo.astype(np.uint8)

# %%
prediction = layers.get_output(deconv['output'], deterministic=False)
test_fun = theano.function([input_var2], prediction)

class_index = 17

labels = np.argmax(test[1],axis=1)
map_index = np.where(labels == class_index)[0]
for index in map_index[:20]:
    
    y = np.expand_dims(output2[index,:],0)
    prediction = test_fun(y.astype(np.float32))
    class_index = np.argmax(test[1][index,:])

    height=100
    bp_width=20
    size = (25.,10.0)

    logo = seq_logo(np.squeeze(test[0][index]), height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');

    logo = seq_logo(test[2][index], height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');
    plt.title(str(class_index),fontsize=20)

    logo = seq_logo(np.squeeze(prediction[0]), height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');
    plt.title(str(np.argmax(output2[index,:]))+'; p='+str(np.max(output2[index,:])),fontsize=20)

# %%
prediction = layers.get_output(deconv['output'], deterministic=False)
test_fun = theano.function([input_var2], prediction)


for index in range(40,60):

    y = np.expand_dims(output2[index,:],0)
    prediction = test_fun(y.astype(np.float32))
    class_index = np.argmax(test[1][index,:])

    height=100
    bp_width=20
    size = (25.,10.0)

    logo = seq_logo(np.squeeze(test[0][index]), height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');

    logo = seq_logo(test[2][index], height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');
    plt.title(str(class_index),fontsize=20)

    logo = seq_logo(np.squeeze(prediction[0]), height, bp_width, norm=0, rna=1, filepath='.')
    fig = plt.figure(figsize=size);
    plt.imshow(logo, interpolation='none');
    plt.axis('off');
    plt.title(str(np.argmax(output2[index,:]))+'; p='+str(np.max(output2[index,:])),fontsize=20)

# %%
savename = 'unlocalized'

# %%
def plot_conv_filter(layer,size):
    W =  np.squeeze(layer.W.get_value())
    num_filters = W.shape[0]

    num_rows = int(np.ceil(np.sqrt(num_filters)))    
    grid = mpl.gridspec.GridSpec(num_rows, num_rows)
    grid.update(wspace=0.2, hspace=0.2, left=0.1, right=0.2, bottom=0.1, top=0.2) 
    
    fig = plt.figure(figsize=size);
    for i in range(num_filters):
        MIN = np.min(W[i])
        MAX = np.max(W[i])
        pwm = (W[i] - MIN)#/(MAX-MIN)
        norm = np.outer(np.ones(4), np.sum(pwm, axis=0))
        pwm = pwm/norm

        logo = seq_logo(pwm, height=100, nt_width=25, norm=0, rna=1, filepath='.')
        plt.subplot(grid[i]);
        plt.imshow(logo);
        plt.axis('off');
    return fig, plt
# %config InlineBackend.close_figures = False
fig, plt = plot_conv_filter(network['conv1'],size=(100.,100.))
fig.set_size_inches(100,100)

outfile = savename +'_filter1.pdf'
fig.savefig(outfile, format='pdf', dpi=1000)  
call(['pdfcrop', outfile, outfile])

# %%
X = test[0]
input_var = nnmodel.input_var
layer = network['conv1_active']

# setup theano function to get feature map of a given layer
num_data = len(X)
feature_maps = theano.function([input_var], layers.get_output(layer), allow_input_downcast=True)
map_shape = get_output_shape(layer)

# get feature maps in batches for speed (large batches may be too much memory for GPU)
num_batches = num_data // batch_size
shape = list(map_shape)
shape[0] = num_data
fmaps = np.empty(tuple(shape))
for i in range(num_batches):
    index = range(i*batch_size, (i+1)*batch_size)    
    fmaps[index] = feature_maps(X[index])

# get the rest of the feature maps
excess = num_data-num_batches*batch_size
index = range(num_data-excess, num_data)    
fmaps[index] = feature_maps(X[index])

# %%
def get_class_activation(fmaps, y, batch_size=512):
    fmaps = np.squeeze(fmaps)
    mean_activation = []
    std_activation = []
    for i in range(max(y)+1):
        index = np.where(y == i)[0]
        mean_activation.append(np.mean(fmaps[index], axis=0))
        std_activation.append(np.std(fmaps[index], axis=0))
    return np.array(mean_activation), np.array(std_activation)


def plot_mean_activations(mean_activation, options):
    num_labels = len(mean_activation)
    nrows = np.ceil(np.sqrt(num_labels)).astype(int)
    ncols = nrows

    plt.figure()
    grid = mpl.gridspec.GridSpec(nrows, ncols)
    grid.update(wspace=0.2, hspace=0.2, left=0.1, right=0.2, bottom=0.1, top=0.2) 
    
    for i in range(num_labels):
        plt.subplot(grid[i])
        plt.plot(mean_activation[i].T)
        fig_options(plt, options)
    return plt

def fig_options(plt, options):
    if 'figsize' in options:
        fig = plt.gcf()
        fig.set_size_inches(options['figsize'][0], options['figsize'][1], forward=True)
    if 'ylim' in options:
        plt.ylim(options['ylim'][0],options['ylim'][1])
    if 'yticks' in options:
        plt.yticks(options['yticks'])
    if 'xticks' in options:
        plt.xticks(options['xticks'])
    if 'labelsize' in options:        
        ax = plt.gca()
        ax.tick_params(axis='x', labelsize=options['labelsize'])
        ax.tick_params(axis='y', labelsize=options['labelsize'])
    if 'axis' in options:
        plt.axis(options['axis'])
    if 'xlabel' in options:
        plt.xlabel(options['xlabel'], fontsize=options['fontsize'])
    if 'ylabel' in options:
        plt.ylabel(options['ylabel'], fontsize=options['fontsize'])
    if 'linewidth' in options:
        plt.rc('axes', linewidth=options['linewidth'])
        

        
mean_activation, std_activation = get_class_activation(fmaps, np.argmax(test[1],axis=1))
options = { 'ylim': [0, 4],
            'xticks': [0, 50, 100, 150],
            'yticks': [0.5, 1.5, 2.5, 3.5], 
            'labelsize': 18,
            'figsize': (150,100)}
plt = plot_mean_activations(mean_activation, options)
#plt.savefig('categorical_l1_activation.eps', format='eps', dpi=1000)
